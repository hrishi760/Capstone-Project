# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

# %%
import tensorflow as tf

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_parquet("without_CID.parquet")


print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (287806, 26)
#    PPI_LEN  PPI_ROUNDTRIPS  log_ppi_duration  log_mean_ipt  log_std_ipt  \
# 0       30               7          0.031499      0.725937     1.249640
# 1       30               5          1.592902      4.879767     6.445720
# 2       19               6          0.158712      2.307834     3.386832
# 3       13               3          0.076961      1.967650     2.883625
# 4       23               5          0.249980      2.591354     3.277578
#
#    mean_packet_size  std_packet_size  direction_change_ratio  \
# 0        966.433333       496.378262                0.482759
# 1        431.633333       497.956055                0.310345
# 2        306.157895       459.089518                0.666667
# 3        444.230769       517.949085                0.416667
# 4        559.217391       538.014624                0.409091
#
#    forward_packet_ratio  src_size_entropy  ...  log_byte_rate  \
# 0              0.466667          0.525992  ...       8.992109
# 1              0.566667          0.656604  ...       8.132042
# 2              0.526316          0.586988  ...      10.516724
# 3              0.307692          0.270426  ...      11.247659
# 4              0.434783          0.431821  ...      10.769836
#
#    avg_packet_size  log_byte_ratio  log_packet_ratio  quic_version_id  \
# 0       849.000000        0.458604          0.503905                1
# 1       419.382353        0.585601          0.818310                1
# 2       334.157895        1.036035          0.747214                1
# 3       472.230769        0.967936          0.367725                1
# 4       587.217391        0.851155          0.570545                3
#
#    QUIC_TOKEN_LENGTH  log_zero_rtt  zero_rtt_present  log_multiplexed  \
# 0                  0      1.791759                 1         1.098612
# 1                  0      0.000000                 0         0.000000
# 2                  0      0.693147                 1         0.000000
# 3                  0      0.000000                 0         0.000000
# 4                  0      0.000000                 0         0.000000
#
#    multiplexed
# 0            1
# 1            0
# 2            0
# 3            0
# 4            0
#
# [5 rows x 26 columns]

# %%
X_train, X_test = train_test_split(
    df,
    test_size=0.20,
    random_state=42,
    shuffle=True
)

print("Training Shape :", X_train.shape)
print("Testing Shape  :", X_test.shape)
# Out:
# Training Shape : (230244, 26)
# Testing Shape  : (57562, 26)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(
    X_train_scaled,
    columns=df.columns,
    index=X_train.index
)

X_test_scaled = pd.DataFrame(
    X_test_scaled,
    columns=df.columns,
    index=X_test.index
)

# %%
from tensorflow.keras.layers import (
    Input, Dense, Dropout
)
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping


input_dim = X_train_scaled.shape[1]

input_layer = Input(shape=(input_dim,))

# Encoder
x = Dense(
    64,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(input_layer)
x = Dropout(0.1)(x)

x = Dense(
    32,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(x)
x = Dropout(0.1)(x)

x = Dense(
    16,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(x)

# Latent Space
latent = Dense(
    10,
    activation='linear',
    name='latent'
)(x)

# Decoder
x = Dense(16, activation='relu')(latent)
x = Dense(32, activation='relu')(x)
x = Dense(64, activation='relu')(x)

output_layer = Dense(
    input_dim,
    activation='linear'
)(x)

autoencoder = Model(input_layer, output_layer)
encoder_model = Model(input_layer, latent)

autoencoder.compile(
    optimizer='adam',
    loss='mse'
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

history = autoencoder.fit(
    X_train_scaled,
    X_train_scaled,
    epochs=200,
    batch_size=2048,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.6590 - val_loss: 0.3614
# Epoch 2/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.3078 - val_loss: 0.2104
# Epoch 3/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.2206 - val_loss: 0.1550
# Epoch 4/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1860 - val_loss: 0.1324
# Epoch 5/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1682 - val_loss: 0.1190
# Epoch 6/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1558 - val_loss: 0.1091
# Epoch 7/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.1479 - val_loss: 0.1034
# Epoch 8/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.1413 - val_loss: 0.0995
# Epoch 9/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1371 - val_loss: 0.0953
# Epoch 10/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1330 - val_loss: 0.0932
# Epoch 11/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.1299 - val_loss: 0.0911
# Epoch 12/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.1273 - val_loss: 0.0889
# Epoch 13/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1242 - val_loss: 0.0868
# Epoch 14/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1216 - val_loss: 0.0841
# Epoch 15/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.1187 - val_loss: 0.0819
# Epoch 16/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1158 - val_loss: 0.0797
# Epoch 17/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1123 - val_loss: 0.0773
# Epoch 18/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1094 - val_loss: 0.0750
# Epoch 19/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1071 - val_loss: 0.0726
# Epoch 20/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.1047 - val_loss: 0.0705
# Epoch 21/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1024 - val_loss: 0.0683
# Epoch 22/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.1007 - val_loss: 0.0662
# Epoch 23/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0988 - val_loss: 0.0661
# Epoch 24/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0975 - val_loss: 0.0645
# Epoch 25/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0958 - val_loss: 0.0644
# Epoch 26/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0948 - val_loss: 0.0628
# Epoch 27/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0932 - val_loss: 0.0617
# Epoch 28/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0918 - val_loss: 0.0620
# Epoch 29/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0909 - val_loss: 0.0613
# Epoch 30/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0900 - val_loss: 0.0604
# Epoch 31/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0886 - val_loss: 0.0617
# Epoch 32/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0879 - val_loss: 0.0595
# Epoch 33/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0869 - val_loss: 0.0592
# Epoch 34/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0860 - val_loss: 0.0592
# Epoch 35/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0853 - val_loss: 0.0589
# Epoch 36/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0846 - val_loss: 0.0598
# Epoch 37/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0839 - val_loss: 0.0583
# Epoch 38/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0830 - val_loss: 0.0577
# Epoch 39/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0820 - val_loss: 0.0560
# Epoch 40/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0814 - val_loss: 0.0566
# Epoch 41/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0807 - val_loss: 0.0561
# Epoch 42/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0805 - val_loss: 0.0557
# Epoch 43/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0790 - val_loss: 0.0547
# Epoch 44/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0785 - val_loss: 0.0532
# Epoch 45/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0777 - val_loss: 0.0534
# Epoch 46/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0769 - val_loss: 0.0537
# Epoch 47/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0762 - val_loss: 0.0527
# Epoch 48/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0754 - val_loss: 0.0532
# Epoch 49/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0751 - val_loss: 0.0520
# Epoch 50/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0743 - val_loss: 0.0534
# Epoch 51/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0736 - val_loss: 0.0524
# Epoch 52/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0728 - val_loss: 0.0516
# Epoch 53/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0726 - val_loss: 0.0507
# Epoch 54/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0718 - val_loss: 0.0512
# Epoch 55/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0714 - val_loss: 0.0518
# Epoch 56/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0710 - val_loss: 0.0494
# Epoch 57/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0704 - val_loss: 0.0493
# Epoch 58/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0701 - val_loss: 0.0503
# Epoch 59/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0695 - val_loss: 0.0491
# Epoch 60/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0692 - val_loss: 0.0501
# Epoch 61/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0685 - val_loss: 0.0503
# Epoch 62/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0684 - val_loss: 0.0482
# Epoch 63/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0680 - val_loss: 0.0499
# Epoch 64/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0675 - val_loss: 0.0497
# Epoch 65/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0673 - val_loss: 0.0481
# Epoch 66/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0671 - val_loss: 0.0496
# Epoch 67/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0669 - val_loss: 0.0485
# Epoch 68/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0662 - val_loss: 0.0480
# Epoch 69/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0665 - val_loss: 0.0486
# Epoch 70/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0659 - val_loss: 0.0484
# Epoch 71/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0654 - val_loss: 0.0475
# Epoch 72/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0653 - val_loss: 0.0492
# Epoch 73/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0652 - val_loss: 0.0473
# Epoch 74/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0649 - val_loss: 0.0483
# Epoch 75/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0647 - val_loss: 0.0491
# Epoch 76/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0646 - val_loss: 0.0492
# Epoch 77/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0644 - val_loss: 0.0482
# Epoch 78/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0640 - val_loss: 0.0493
# Epoch 79/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0638 - val_loss: 0.0488
# Epoch 80/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0639 - val_loss: 0.0500
# Epoch 81/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0635 - val_loss: 0.0486
# Epoch 82/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0633 - val_loss: 0.0481
# Epoch 83/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0632 - val_loss: 0.0492
# Epoch 84/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0627 - val_loss: 0.0497
# Epoch 85/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0630 - val_loss: 0.0486
# Epoch 86/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0624 - val_loss: 0.0499
# Epoch 87/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0621 - val_loss: 0.0486
# Epoch 88/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0619 - val_loss: 0.0493
# Epoch 88: early stopping
# Restoring model weights from the end of the best epoch: 73.

# %%
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 26)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           1,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ latent (Dense)                       │ (None, 10)                  │             170 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 26)                  │           1,690 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 27,086 (105.81 KB)
#  Trainable params: 9,028 (35.27 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 18,058 (70.54 KB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Autoencoder Training")

plt.legend()

plt.show()

# %%
latent_train = encoder_model.predict(X_train_scaled)

latent_test = encoder_model.predict(X_test_scaled)

print("Train:", latent_train.shape)
print("Test :", latent_test.shape)
# Out:
# 7196/7196 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step
# 1799/1799 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Train: (230244, 10)
# Test : (57562, 10)

# %%
latent_columns = [f"latent_{i+1}" for i in range(10)]

latent_train = pd.DataFrame(
    latent_train,
    columns=latent_columns
)

latent_test = pd.DataFrame(
    latent_test,
    columns=latent_columns
)

# %%
latent_test.hist(
    figsize=(15,8),
    bins=30
)

plt.tight_layout()
plt.show()

# %%
iso_forest = IsolationForest(
    n_estimators=200,
    contamination="auto",
    random_state=42,
    n_jobs=-1
)

# %%
iso_forest.fit(latent_train)
# Out:
# IsolationForest(n_estimators=200, n_jobs=-1, random_state=42)

# %%
predictions = iso_forest.predict(latent_test)
anomaly_scores = -iso_forest.score_samples(latent_test)

# %%
results = latent_test.copy()

results["anomaly_score"] = anomaly_scores

results["prediction"] = predictions

results.head()
# Out:
#    latent_1  latent_2  latent_3  latent_4  latent_5  latent_6  latent_7  \
# 0 -2.396172  3.160956  0.160915  0.194575 -0.909085  0.785746  2.230259
# 1 -1.474681  2.994741 -1.000488  1.137256 -1.081531  1.134838  2.745596
# 2 -4.088043  2.971686 -0.922706  4.649504 -2.185973  2.681679  8.597218
# 3 -3.028396  7.276918 -0.510377  4.791970 -1.109088  0.774442  4.875943
# 4 -1.453411  2.623995  0.124191  1.657475  0.142120  0.946879  3.015044
#
#    latent_8  latent_9  latent_10  anomaly_score  prediction
# 0  0.637226 -0.546450  -0.917784       0.372522           1
# 1  0.062526  0.030595  -0.668895       0.379774           1
# 2  2.645429  0.137611   0.087654       0.610993          -1
# 3  1.352001 -1.422444  -1.932138       0.523699          -1
# 4  0.294880 -0.253470  -0.746481       0.376199           1

# %%
plt.figure(figsize=(8,5))

plt.hist(anomaly_scores,
         bins=50)

plt.xlabel("Anomaly Score")

plt.ylabel("Number of Flows")

plt.title("Isolation Forest Anomaly Score Distribution")

plt.show()

# %%
score_series = pd.Series(anomaly_scores)

print(score_series.describe())

print("\nSkewness:", score_series.skew())
# Out:
# count    57562.000000
# mean         0.419451
# std          0.067721
# min          0.349081
# 25%          0.373760
# 50%          0.394347
# 75%          0.437768
# max          0.741556
# dtype: float64
#
# Skewness: 1.7953908368961082

# %%
print("Normal flows :", np.sum(predictions == 1))
print("Anomalous flows :", np.sum(predictions == -1))
# Out:
# Normal flows : 50269
# Anomalous flows : 7293

# %%
results = df.loc[X_test.index].copy()
results["anomaly_score"] = anomaly_scores

# %%
threshold = np.percentile(anomaly_scores, 95)

normal = results[results["anomaly_score"] < threshold]
anomalous = results[results["anomaly_score"] >= threshold]

print("Normal flows:", len(normal))
print("Anomalous flows:", len(anomalous))
# Out:
# Normal flows: 54683
# Anomalous flows: 2879

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

latent_pca = pca.fit_transform(latent_test)

# %%
plt.figure(figsize=(8,6))

scatter = plt.scatter(
    latent_pca[:,0],
    latent_pca[:,1],
    c=anomaly_scores,
    cmap="viridis",
    s=10
)

plt.colorbar(scatter, label="Anomaly Score")

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.title("Latent Space Representation of QUIC Flows")

plt.show()

# %%
seeds = [42, 100, 200, 500]


score_df = pd.DataFrame(index=latent_test.index)

for seed in seeds:

    iso = IsolationForest(
        n_estimators=200,
        contamination="auto",
        random_state=seed
    )

    iso.fit(latent_train)

    score_df[f"Seed_{seed}"] = -iso.score_samples(latent_test)

score_df.head()
# Out:
#     Seed_42  Seed_100  Seed_200  Seed_500
# 0  0.372522  0.378897  0.371653  0.378702
# 1  0.379774  0.381932  0.376192  0.377952
# 2  0.610993  0.588521  0.590325  0.593523
# 3  0.523699  0.505434  0.507410  0.516546
# 4  0.376199  0.381983  0.376219  0.375964

# %%
correlation = score_df.corr()

correlation
# Out:
#            Seed_42  Seed_100  Seed_200  Seed_500
# Seed_42   1.000000  0.991379  0.991558  0.993300
# Seed_100  0.991379  1.000000  0.988678  0.989501
# Seed_200  0.991558  0.988678  1.000000  0.988900
# Seed_500  0.993300  0.989501  0.988900  1.000000

# %%
top_anomalies = {}

for column in score_df.columns:

    threshold = score_df[column].quantile(0.95)

    top_anomalies[column] = set(
        score_df.index[
            score_df[column] >= threshold
        ]
    )

# %%
from itertools import combinations

overlap_results = []

for seed_1, seed_2 in combinations(score_df.columns, 2):

    common = len(
        top_anomalies[seed_1].intersection(
            top_anomalies[seed_2]
        )
    )

    total = len(top_anomalies[seed_1])

    overlap = (common / total) * 100

    overlap_results.append([
        seed_1,
        seed_2,
        common,
        round(overlap,2)
    ])

overlap_df = pd.DataFrame(
    overlap_results,
    columns=[
        "Seed 1",
        "Seed 2",
        "Common Anomalies",
        "Overlap (%)"
    ]
)

overlap_df
# Out:
#      Seed 1    Seed 2  Common Anomalies  Overlap (%)
# 0   Seed_42  Seed_100              2727        94.72
# 1   Seed_42  Seed_200              2705        93.96
# 2   Seed_42  Seed_500              2672        92.81
# 3  Seed_100  Seed_200              2692        93.50
# 4  Seed_100  Seed_500              2662        92.46
# 5  Seed_200  Seed_500              2627        91.25

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Reduce latent space to 2D
pca = PCA(n_components=2, random_state=42)
latent_pca = pca.fit_transform(latent_test)

# Boolean masks
normal_mask = predictions == 1
anomaly_mask = predictions == -1

plt.figure(figsize=(10,8))

# Normal flows
plt.scatter(
    latent_pca[normal_mask,0],
    latent_pca[normal_mask,1],
    s=10,
    c='lightgrey',
    alpha=0.35,
    label='Normal'
)

# Anomalies
plt.scatter(
    latent_pca[anomaly_mask,0],
    latent_pca[anomaly_mask,1],
    s=18,
    c='red',
    alpha=0.85,
    label='Predicted Anomaly'
)

plt.xlabel(f"Principal Component 1 ({pca.explained_variance_ratio_[0]*100:.2f}%)")
plt.ylabel(f"Principal Component 2 ({pca.explained_variance_ratio_[1]*100:.2f}%)")
plt.title("Latent Space PCA with Isolation Forest Predictions")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette = silhouette_score(latent_test, predictions)

print(f"Silhouette Score: {silhouette:.4f}")
# Out:
# Silhouette Score: 0.5056

# %%
from sklearn.metrics import davies_bouldin_score

db_index = davies_bouldin_score(latent_test, predictions)

print(f"Davies-Bouldin Index: {db_index:.4f}")
# Out:
# Davies-Bouldin Index: 1.6973

# %%
results_df = pd.DataFrame(
    latent_test,
    columns=[f"latent_{i+1}" for i in range(latent_test.shape[1])]
)

results_df["flow_index"] = X_test.index
results_df["anomaly_score"] = anomaly_scores
results_df["prediction"] = predictions

# Put flow_index first
results_df = results_df[
    ["flow_index"] +
    [c for c in results_df.columns if c != "flow_index"]
]

results_df.head()
# Out:
#    flow_index  latent_1  latent_2  latent_3  latent_4  latent_5  latent_6  \
# 0      159464 -2.396172  3.160956  0.160915  0.194575 -0.909085  0.785746
# 1      115420 -1.474681  2.994741 -1.000488  1.137256 -1.081531  1.134838
# 2       53464 -4.088043  2.971686 -0.922706  4.649504 -2.185973  2.681679
# 3      192817 -3.028396  7.276918 -0.510377  4.791970 -1.109088  0.774442
# 4      186365 -1.453411  2.623995  0.124191  1.657475  0.142120  0.946879
#
#    latent_7  latent_8  latent_9  latent_10  anomaly_score  prediction
# 0  2.230259  0.637226 -0.546450  -0.917784       0.372522           1
# 1  2.745596  0.062526  0.030595  -0.668895       0.379774           1
# 2  8.597218  2.645429  0.137611   0.087654       0.610993          -1
# 3  4.875943  1.352001 -1.422444  -1.932138       0.523699          -1
# 4  3.015044  0.294880 -0.253470  -0.746481       0.376199           1

# %%
results_df.to_parquet(
    "without_CID_results.parquet",
    index=False
)

# %%
X_test.to_parquet("without_CID_test_features.parquet")
