# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

# %%
import tensorflow as tf

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_parquet("with_CID.parquet")


print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (728592, 40)
#    PPI_LEN  PPI_ROUNDTRIPS  log_ppi_duration  log_mean_ipt  log_std_ipt  \
# 0       30               6          0.104360      1.540445     2.011873
# 1       30               3          0.010940      0.312375     0.717000
# 2       30               6          0.810041      3.751854     5.377717
# 3       23               6          0.094401      1.668527     2.072350
# 4       28               7          0.132781      1.803594     2.261974
#
#    mean_packet_size  std_packet_size  direction_change_ratio  \
# 0        435.633333       504.944649                0.413793
# 1        629.766667       557.518351                0.172414
# 2        488.966667       517.350267                0.379310
# 3        568.173913       557.311220                0.500000
# 4        408.500000       520.425478                0.481481
#
#    forward_packet_ratio  occid_length  ...  log_byte_rate  avg_packet_size  \
# 0              0.466667             0  ...       7.377019       700.055556
# 1              0.266667             0  ...      13.720225      1157.797076
# 2              0.433333             0  ...      11.469826      1177.305864
# 3              0.565217             0  ...      11.876110       616.173913
# 4              0.571429             0  ...      11.365379       436.500000
#
#    log_byte_ratio  log_packet_ratio  quic_version_id  QUIC_TOKEN_LENGTH  \
# 0        0.158156          0.453474                1                 70
# 1        0.005772          0.102005                1                 65
# 2        0.008245          0.081001                1                  0
# 3        1.671815          0.832909                1                 70
# 4        0.546246          0.847298                1                  0
#
#    log_zero_rtt  zero_rtt_present  log_multiplexed  multiplexed
# 0      0.693147                 1              0.0            0
# 1      0.693147                 1              0.0            0
# 2      0.000000                 0              0.0            0
# 3      0.000000                 0              0.0            0
# 4      0.000000                 0              0.0            0
#
# [5 rows x 40 columns]

# %%
X_train, X_test = train_test_split(
    df,
    test_size=0.20,
    random_state=42,
    shuffle=True
)

print("Training Shape :", X_train.shape)
print("Testing Shape  :", X_test.shape)
# Out:
# Training Shape : (582873, 40)
# Testing Shape  : (145719, 40)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(
    X_train_scaled,
    columns=df.columns,
    index=X_train.index
)

X_test_scaled = pd.DataFrame(
    X_test_scaled,
    columns=df.columns,
    index=X_test.index
)

# %%
from tensorflow.keras.layers import (
    Input, Dense, Dropout
)
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping


input_dim = X_train_scaled.shape[1]

input_layer = Input(shape=(input_dim,))

# Encoder
x = Dense(
    64,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(input_layer)
x = Dropout(0.1)(x)

x = Dense(
    32,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(x)
x = Dropout(0.1)(x)

x = Dense(
    16,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(x)

# Latent Space
latent = Dense(
    10,
    activation='linear',
    name='latent'
)(x)

# Decoder
x = Dense(16, activation='relu')(latent)
x = Dense(32, activation='relu')(x)
x = Dense(64, activation='relu')(x)

output_layer = Dense(
    input_dim,
    activation='linear'
)(x)

autoencoder = Model(input_layer, output_layer)
encoder_model = Model(input_layer, latent)

autoencoder.compile(
    optimizer='adam',
    loss='mse'
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

history = autoencoder.fit(
    X_train_scaled,
    X_train_scaled,
    epochs=200,
    batch_size=2048,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.5567 - val_loss: 0.3237
# Epoch 2/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.3189 - val_loss: 0.2434
# Epoch 3/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.2578 - val_loss: 0.1939
# Epoch 4/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2283 - val_loss: 0.1755
# Epoch 5/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2140 - val_loss: 0.1641
# Epoch 6/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.2036 - val_loss: 0.1552
# Epoch 7/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1960 - val_loss: 0.1466
# Epoch 8/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.1884 - val_loss: 0.1412
# Epoch 9/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1810 - val_loss: 0.1359
# Epoch 10/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1770 - val_loss: 0.1310
# Epoch 11/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1714 - val_loss: 0.1262
# Epoch 12/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.1669 - val_loss: 0.1212
# Epoch 13/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1627 - val_loss: 0.1184
# Epoch 14/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1613 - val_loss: 0.1177
# Epoch 15/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.1577 - val_loss: 0.1137
# Epoch 16/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.1551 - val_loss: 0.1136
# Epoch 17/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1541 - val_loss: 0.1113
# Epoch 18/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.1517 - val_loss: 0.1101
# Epoch 19/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1499 - val_loss: 0.1090
# Epoch 20/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1489 - val_loss: 0.1088
# Epoch 21/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.1459 - val_loss: 0.1046
# Epoch 22/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1443 - val_loss: 0.1053
# Epoch 23/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1435 - val_loss: 0.1053
# Epoch 24/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1427 - val_loss: 0.1030
# Epoch 25/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1410 - val_loss: 0.1027
# Epoch 26/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1386 - val_loss: 0.1015
# Epoch 27/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1373 - val_loss: 0.1004
# Epoch 28/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1369 - val_loss: 0.0995
# Epoch 29/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1360 - val_loss: 0.0987
# Epoch 30/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1343 - val_loss: 0.0985
# Epoch 31/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1328 - val_loss: 0.0953
# Epoch 32/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1325 - val_loss: 0.0957
# Epoch 33/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1310 - val_loss: 0.0947
# Epoch 34/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1301 - val_loss: 0.0924
# Epoch 35/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1285 - val_loss: 0.0920
# Epoch 36/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.1270 - val_loss: 0.0885
# Epoch 37/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1270 - val_loss: 0.0902
# Epoch 38/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1247 - val_loss: 0.0871
# Epoch 39/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1242 - val_loss: 0.0858
# Epoch 40/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1230 - val_loss: 0.0859
# Epoch 41/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1219 - val_loss: 0.0859
# Epoch 42/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1205 - val_loss: 0.0871
# Epoch 43/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1203 - val_loss: 0.0838
# Epoch 44/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1193 - val_loss: 0.0836
# Epoch 45/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1187 - val_loss: 0.0828
# Epoch 46/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1177 - val_loss: 0.0834
# Epoch 47/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1176 - val_loss: 0.0806
# Epoch 48/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1159 - val_loss: 0.0808
# Epoch 49/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1152 - val_loss: 0.0809
# Epoch 50/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.1147 - val_loss: 0.0803
# Epoch 51/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.1143 - val_loss: 0.0809
# Epoch 52/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.1140 - val_loss: 0.0814
# Epoch 53/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.1130 - val_loss: 0.0802
# Epoch 54/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.1122 - val_loss: 0.0789
# Epoch 55/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1121 - val_loss: 0.0778
# Epoch 56/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1112 - val_loss: 0.0763
# Epoch 57/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1107 - val_loss: 0.0786
# Epoch 58/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.1100 - val_loss: 0.0765
# Epoch 59/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1098 - val_loss: 0.0772
# Epoch 60/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1093 - val_loss: 0.0751
# Epoch 61/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1089 - val_loss: 0.0742
# Epoch 62/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1099 - val_loss: 0.0753
# Epoch 63/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1078 - val_loss: 0.0761
# Epoch 64/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1070 - val_loss: 0.0742
# Epoch 65/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1068 - val_loss: 0.0745
# Epoch 66/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1066 - val_loss: 0.0727
# Epoch 67/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1058 - val_loss: 0.0739
# Epoch 68/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1060 - val_loss: 0.0739
# Epoch 69/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1052 - val_loss: 0.0731
# Epoch 70/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1051 - val_loss: 0.0727
# Epoch 71/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1045 - val_loss: 0.0727
# Epoch 72/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1039 - val_loss: 0.0726
# Epoch 73/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1036 - val_loss: 0.0717
# Epoch 74/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1039 - val_loss: 0.0721
# Epoch 75/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1039 - val_loss: 0.0736
# Epoch 76/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1030 - val_loss: 0.0708
# Epoch 77/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1026 - val_loss: 0.0705
# Epoch 78/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1026 - val_loss: 0.0702
# Epoch 79/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1024 - val_loss: 0.0696
# Epoch 80/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1014 - val_loss: 0.0713
# Epoch 81/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1014 - val_loss: 0.0704
# Epoch 82/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1015 - val_loss: 0.0703
# Epoch 83/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1016 - val_loss: 0.0694
# Epoch 84/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1007 - val_loss: 0.0693
# Epoch 85/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1006 - val_loss: 0.0691
# Epoch 86/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1002 - val_loss: 0.0697
# Epoch 87/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1004 - val_loss: 0.0700
# Epoch 88/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0996 - val_loss: 0.0693
# Epoch 89/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1014 - val_loss: 0.0676
# Epoch 90/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0997 - val_loss: 0.0688
# Epoch 91/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0987 - val_loss: 0.0685
# Epoch 92/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0989 - val_loss: 0.0692
# Epoch 93/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0983 - val_loss: 0.0677
# Epoch 94/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0978 - val_loss: 0.0688
# Epoch 95/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0985 - val_loss: 0.0679
# Epoch 96/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0973 - val_loss: 0.0670
# Epoch 97/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0986 - val_loss: 0.0677
# Epoch 98/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0970 - val_loss: 0.0688
# Epoch 99/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0973 - val_loss: 0.0661
# Epoch 100/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0969 - val_loss: 0.0686
# Epoch 101/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0964 - val_loss: 0.0663
# Epoch 102/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0967 - val_loss: 0.0671
# Epoch 103/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0967 - val_loss: 0.0676
# Epoch 104/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0964 - val_loss: 0.0667
# Epoch 105/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0964 - val_loss: 0.0686
# Epoch 106/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0955 - val_loss: 0.0658
# Epoch 107/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0958 - val_loss: 0.0666
# Epoch 108/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0950 - val_loss: 0.0665
# Epoch 109/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0954 - val_loss: 0.0652
# Epoch 110/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0952 - val_loss: 0.0714
# Epoch 111/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0953 - val_loss: 0.0660
# Epoch 112/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0944 - val_loss: 0.0651
# Epoch 113/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0950 - val_loss: 0.0654
# Epoch 114/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0957 - val_loss: 0.0656
# Epoch 115/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0941 - val_loss: 0.0643
# Epoch 116/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0937 - val_loss: 0.0659
# Epoch 117/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0940 - val_loss: 0.0645
# Epoch 118/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0934 - val_loss: 0.0643
# Epoch 119/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0930 - val_loss: 0.0649
# Epoch 120/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0937 - val_loss: 0.0658
# Epoch 121/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0928 - val_loss: 0.0644
# Epoch 122/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0925 - val_loss: 0.0647
# Epoch 123/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0932 - val_loss: 0.0647
# Epoch 124/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0923 - val_loss: 0.0664
# Epoch 125/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0921 - val_loss: 0.0642
# Epoch 126/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0925 - val_loss: 0.0639
# Epoch 127/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0927 - val_loss: 0.0647
# Epoch 128/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0919 - val_loss: 0.0646
# Epoch 129/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0915 - val_loss: 0.0627
# Epoch 130/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0917 - val_loss: 0.0651
# Epoch 131/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0919 - val_loss: 0.0630
# Epoch 132/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0912 - val_loss: 0.0626
# Epoch 133/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0917 - val_loss: 0.0632
# Epoch 134/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0910 - val_loss: 0.0631
# Epoch 135/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0910 - val_loss: 0.0632
# Epoch 136/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0901 - val_loss: 0.0620
# Epoch 137/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0904 - val_loss: 0.0614
# Epoch 138/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0900 - val_loss: 0.0622
# Epoch 139/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0910 - val_loss: 0.0635
# Epoch 140/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0901 - val_loss: 0.0634
# Epoch 141/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0900 - val_loss: 0.0621
# Epoch 142/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0895 - val_loss: 0.0607
# Epoch 143/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0899 - val_loss: 0.0626
# Epoch 144/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0902 - val_loss: 0.0614
# Epoch 145/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0893 - val_loss: 0.0637
# Epoch 146/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0893 - val_loss: 0.0631
# Epoch 147/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0900 - val_loss: 0.0614
# Epoch 148/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0893 - val_loss: 0.0629
# Epoch 149/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0888 - val_loss: 0.0612
# Epoch 150/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0888 - val_loss: 0.0627
# Epoch 151/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0892 - val_loss: 0.0612
# Epoch 152/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0885 - val_loss: 0.0607
# Epoch 153/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0885 - val_loss: 0.0604
# Epoch 154/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0886 - val_loss: 0.0600
# Epoch 155/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0897 - val_loss: 0.0613
# Epoch 156/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0892 - val_loss: 0.0610
# Epoch 157/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0890 - val_loss: 0.0608
# Epoch 158/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0882 - val_loss: 0.0617
# Epoch 159/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0885 - val_loss: 0.0631
# Epoch 160/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0876 - val_loss: 0.0612
# Epoch 161/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0887 - val_loss: 0.0608
# Epoch 162/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0882 - val_loss: 0.0621
# Epoch 163/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0874 - val_loss: 0.0621
# Epoch 164/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0880 - val_loss: 0.0619
# Epoch 165/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0883 - val_loss: 0.0618
# Epoch 166/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0884 - val_loss: 0.0617
# Epoch 167/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0873 - val_loss: 0.0595
# Epoch 168/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0880 - val_loss: 0.0618
# Epoch 169/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0874 - val_loss: 0.0629
# Epoch 170/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0871 - val_loss: 0.0606
# Epoch 171/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0874 - val_loss: 0.0608
# Epoch 172/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0869 - val_loss: 0.0608
# Epoch 173/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0873 - val_loss: 0.0632
# Epoch 174/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0875 - val_loss: 0.0598
# Epoch 175/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0869 - val_loss: 0.0624
# Epoch 176/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0868 - val_loss: 0.0611
# Epoch 177/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0865 - val_loss: 0.0612
# Epoch 178/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0870 - val_loss: 0.0623
# Epoch 179/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0865 - val_loss: 0.0608
# Epoch 180/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0870 - val_loss: 0.0610
# Epoch 181/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0867 - val_loss: 0.0617
# Epoch 182/200
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0871 - val_loss: 0.0609
# Epoch 182: early stopping
# Restoring model weights from the end of the best epoch: 167.

# %%
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 40)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           2,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ latent (Dense)                       │ (None, 10)                  │             170 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 40)                  │           2,600 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 32,504 (126.97 KB)
#  Trainable params: 10,834 (42.32 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 21,670 (84.65 KB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Autoencoder Training")

plt.legend()

plt.show()

# %%
latent_train = encoder_model.predict(X_train_scaled)

latent_test = encoder_model.predict(X_test_scaled)

print("Train:", latent_train.shape)
print("Test :", latent_test.shape)
# Out:
# 18215/18215 ━━━━━━━━━━━━━━━━━━━━ 32s 2ms/step
# 4554/4554 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
# Train: (582873, 10)
# Test : (145719, 10)

# %%
latent_columns = [f"latent_{i+1}" for i in range(10)]

latent_train = pd.DataFrame(
    latent_train,
    columns=latent_columns
)

latent_test = pd.DataFrame(
    latent_test,
    columns=latent_columns
)

# %%
latent_test.hist(
    figsize=(15,8),
    bins=30
)

plt.tight_layout()
plt.show()

# %%
iso_forest = IsolationForest(
    n_estimators=200,
    contamination="auto",
    random_state=42,
    n_jobs=-1
)

# %%
iso_forest.fit(latent_train)
# Out:
# IsolationForest(n_estimators=200, n_jobs=-1, random_state=42)

# %%
predictions = iso_forest.predict(latent_test)
anomaly_scores = -iso_forest.score_samples(latent_test)

# %%
results = latent_test.copy()

results["anomaly_score"] = anomaly_scores

results["prediction"] = predictions

results.head()
# Out:
#    latent_1   latent_2  latent_3  latent_4  latent_5  latent_6   latent_7  \
# 0 -0.081890  -3.586224  0.112447 -0.614410 -1.278555  3.375232  -2.447624
# 1  0.652247  -1.569111 -2.808368  3.364667 -1.293598  2.929409  -4.161932
# 2  2.274229  -0.405829 -3.631678  3.997769 -6.483452 -0.129790  -5.981468
# 3  2.522126  -2.284847 -2.813662  3.899251 -1.530861  3.780728  -1.802472
# 4 -0.467422 -14.233104  5.374492 -3.549207 -8.232038  9.473668 -13.115004
#
#    latent_8  latent_9  latent_10  anomaly_score  prediction
# 0 -2.276172  0.213760  -0.719791       0.410926           1
# 1 -3.753884 -2.236477   0.132340       0.388754           1
# 2 -6.028636 -2.187037  -2.914819       0.467439           1
# 3 -0.829501 -1.691865   0.045850       0.400305           1
# 4 -7.160005 -2.480648  -0.902968       0.611600          -1

# %%
plt.figure(figsize=(8,5))

plt.hist(anomaly_scores,
         bins=50)

plt.xlabel("Anomaly Score")

plt.ylabel("Number of Flows")

plt.title("Isolation Forest Anomaly Score Distribution")

plt.show()

# %%
score_series = pd.Series(anomaly_scores)

print(score_series.describe())

print("\nSkewness:", score_series.skew())
# Out:
# count    145719.000000
# mean          0.427781
# std           0.067224
# min           0.353965
# 25%           0.378799
# 50%           0.406617
# 75%           0.455553
# max           0.782895
# dtype: float64
#
# Skewness: 1.8257995154989124

# %%
print("Normal flows :", np.sum(predictions == 1))
print("Anomalous flows :", np.sum(predictions == -1))
# Out:
# Normal flows : 128473
# Anomalous flows : 17246

# %%
results = df.loc[X_test.index].copy()
results["anomaly_score"] = anomaly_scores

# %%
threshold = np.percentile(anomaly_scores, 95)

normal = results[results["anomaly_score"] < threshold]
anomalous = results[results["anomaly_score"] >= threshold]

print("Normal flows:", len(normal))
print("Anomalous flows:", len(anomalous))
# Out:
# Normal flows: 138433
# Anomalous flows: 7286

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

latent_pca = pca.fit_transform(latent_test)

# %%
plt.figure(figsize=(8,6))

scatter = plt.scatter(
    latent_pca[:,0],
    latent_pca[:,1],
    c=anomaly_scores,
    cmap="viridis",
    s=10
)

plt.colorbar(scatter, label="Anomaly Score")

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.title("Latent Space Representation of QUIC Flows")

plt.show()

# %%
seeds = [42, 100, 200, 500]


score_df = pd.DataFrame(index=latent_test.index)

for seed in seeds:

    iso = IsolationForest(
        n_estimators=200,
        contamination="auto",
        random_state=seed
    )

    iso.fit(latent_train)

    score_df[f"Seed_{seed}"] = -iso.score_samples(latent_test)

score_df.head()
# Out:
#     Seed_42  Seed_100  Seed_200  Seed_500
# 0  0.410926  0.413300  0.426356  0.416200
# 1  0.388754  0.388914  0.377312  0.393883
# 2  0.467439  0.477521  0.457726  0.460132
# 3  0.400305  0.392311  0.391914  0.403905
# 4  0.611600  0.617685  0.604188  0.636123

# %%
correlation = score_df.corr()

correlation
# Out:
#            Seed_42  Seed_100  Seed_200  Seed_500
# Seed_42   1.000000  0.991430  0.990596  0.993084
# Seed_100  0.991430  1.000000  0.988758  0.991778
# Seed_200  0.990596  0.988758  1.000000  0.989407
# Seed_500  0.993084  0.991778  0.989407  1.000000

# %%
top_anomalies = {}

for column in score_df.columns:

    threshold = score_df[column].quantile(0.95)

    top_anomalies[column] = set(
        score_df.index[
            score_df[column] >= threshold
        ]
    )

# %%
from itertools import combinations

overlap_results = []

for seed_1, seed_2 in combinations(score_df.columns, 2):

    common = len(
        top_anomalies[seed_1].intersection(
            top_anomalies[seed_2]
        )
    )

    total = len(top_anomalies[seed_1])

    overlap = (common / total) * 100

    overlap_results.append([
        seed_1,
        seed_2,
        common,
        round(overlap,2)
    ])

overlap_df = pd.DataFrame(
    overlap_results,
    columns=[
        "Seed 1",
        "Seed 2",
        "Common Anomalies",
        "Overlap (%)"
    ]
)

overlap_df
# Out:
#      Seed 1    Seed 2  Common Anomalies  Overlap (%)
# 0   Seed_42  Seed_100              6909        94.83
# 1   Seed_42  Seed_200              6806        93.41
# 2   Seed_42  Seed_500              6875        94.36
# 3  Seed_100  Seed_200              6812        93.49
# 4  Seed_100  Seed_500              6862        94.18
# 5  Seed_200  Seed_500              6970        95.66

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Reduce latent space to 2D
pca = PCA(n_components=2, random_state=42)
latent_pca = pca.fit_transform(latent_test)

# Boolean masks
normal_mask = predictions == 1
anomaly_mask = predictions == -1

plt.figure(figsize=(10,8))

# Normal flows
plt.scatter(
    latent_pca[normal_mask,0],
    latent_pca[normal_mask,1],
    s=10,
    c='lightgrey',
    alpha=0.35,
    label='Normal'
)

# Anomalies
plt.scatter(
    latent_pca[anomaly_mask,0],
    latent_pca[anomaly_mask,1],
    s=18,
    c='red',
    alpha=0.85,
    label='Predicted Anomaly'
)

plt.xlabel(f"Principal Component 1 ({pca.explained_variance_ratio_[0]*100:.2f}%)")
plt.ylabel(f"Principal Component 2 ({pca.explained_variance_ratio_[1]*100:.2f}%)")
plt.title("Latent Space PCA with Isolation Forest Predictions")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette = silhouette_score(latent_test, predictions)

print(f"Silhouette Score: {silhouette:.4f}")
# Out:
# Silhouette Score: 0.5040

# %%
from sklearn.metrics import davies_bouldin_score

db_index = davies_bouldin_score(latent_test, predictions)

print(f"Davies-Bouldin Index: {db_index:.4f}")
# Out:
# Davies-Bouldin Index: 1.7480

# %%
results_df = pd.DataFrame(
    latent_test,
    columns=[f"latent_{i+1}" for i in range(latent_test.shape[1])]
)

results_df["flow_index"] = X_test.index
results_df["anomaly_score"] = anomaly_scores
results_df["prediction"] = predictions

# Put flow_index first
results_df = results_df[
    ["flow_index"] +
    [c for c in results_df.columns if c != "flow_index"]
]

results_df.head()
# Out:
#    flow_index  latent_1   latent_2  latent_3  latent_4  latent_5  latent_6  \
# 0      712720 -0.081890  -3.586224  0.112447 -0.614410 -1.278555  3.375232
# 1      110772  0.652247  -1.569111 -2.808368  3.364667 -1.293598  2.929409
# 2      268199  2.274229  -0.405829 -3.631678  3.997769 -6.483452 -0.129790
# 3      410634  2.522126  -2.284847 -2.813662  3.899251 -1.530861  3.780728
# 4      543227 -0.467422 -14.233104  5.374492 -3.549207 -8.232038  9.473668
#
#     latent_7  latent_8  latent_9  latent_10  anomaly_score  prediction
# 0  -2.447624 -2.276172  0.213760  -0.719791       0.410926           1
# 1  -4.161932 -3.753884 -2.236477   0.132340       0.388754           1
# 2  -5.981468 -6.028636 -2.187037  -2.914819       0.467439           1
# 3  -1.802472 -0.829501 -1.691865   0.045850       0.400305           1
# 4 -13.115004 -7.160005 -2.480648  -0.902968       0.611600          -1

# %%
results_df.to_parquet(
    "with_CID_results.parquet",
    index=False
)

# %%
X_test.to_parquet("with_CID_test_features.parquet")
