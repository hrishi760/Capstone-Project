# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

# %%
import tensorflow as tf

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_parquet("with_CID.parquet")


print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (311084, 40)
#    PPI_LEN  PPI_ROUNDTRIPS  log_ppi_duration  log_mean_ipt  log_std_ipt  \
# 0       30               6          0.114221      1.616082     2.182880
# 1       30               9          0.105261      1.547563     1.857983
# 2       23               5          0.093490      1.660296     2.318133
# 3       22               5          0.333611      2.944439     3.708362
# 4       11               2          0.255417      3.312532     4.329917
#
#    mean_packet_size  std_packet_size  direction_change_ratio  \
# 0        614.100000       576.196341                0.413793
# 1        545.433333       512.401189                0.586207
# 2        478.391304       526.801236                0.454545
# 3        447.181818       530.688715                0.476190
# 4        982.272727       445.369324                0.300000
#
#    forward_packet_ratio  occid_length  ...  log_byte_rate  avg_packet_size  \
# 0              0.366667             6  ...       7.308989       558.053571
# 1              0.433333            32  ...       8.014503       514.600000
# 2              0.565217             0  ...      11.686866       506.391304
# 3              0.545455             0  ...      10.179950       475.181818
# 4              0.363636             0  ...      10.549433      1010.272727
#
#    log_byte_ratio  log_packet_ratio  quic_version_id  QUIC_TOKEN_LENGTH  \
# 0        0.164115          0.528844                1                 70
# 1        0.766629          0.636706                1                 70
# 2        1.306060          0.832909                1                 70
# 3        0.396514          0.788457                1                  0
# 4        0.265230          0.451985                1                  0
#
#    log_zero_rtt  zero_rtt_present  log_multiplexed  multiplexed
# 0      1.098612                 1         0.000000            0
# 1      0.000000                 0         1.098612            1
# 2      0.693147                 1         0.000000            0
# 3      0.000000                 0         0.000000            0
# 4      0.000000                 0         0.000000            0
#
# [5 rows x 40 columns]

# %%
X_train, X_test = train_test_split(
    df,
    test_size=0.20,
    random_state=42,
    shuffle=True
)

print("Training Shape :", X_train.shape)
print("Testing Shape  :", X_test.shape)
# Out:
# Training Shape : (248867, 40)
# Testing Shape  : (62217, 40)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(
    X_train_scaled,
    columns=df.columns,
    index=X_train.index
)

X_test_scaled = pd.DataFrame(
    X_test_scaled,
    columns=df.columns,
    index=X_test.index
)

# %%
from tensorflow.keras.layers import (
    Input, Dense, Dropout
)
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping


input_dim = X_train_scaled.shape[1]

input_layer = Input(shape=(input_dim,))

# Encoder
x = Dense(
    64,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(input_layer)
x = Dropout(0.1)(x)

x = Dense(
    32,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(x)
x = Dropout(0.1)(x)

x = Dense(
    16,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(x)

# Latent Space
latent = Dense(
    10,
    activation='linear',
    name='latent'
)(x)

# Decoder
x = Dense(16, activation='relu')(latent)
x = Dense(32, activation='relu')(x)
x = Dense(64, activation='relu')(x)

output_layer = Dense(
    input_dim,
    activation='linear'
)(x)

autoencoder = Model(input_layer, output_layer)
encoder_model = Model(input_layer, latent)

autoencoder.compile(
    optimizer='adam',
    loss='mse'
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

history = autoencoder.fit(
    X_train_scaled,
    X_train_scaled,
    epochs=200,
    batch_size=2048,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 0.7760 - val_loss: 0.5383
# Epoch 2/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4641 - val_loss: 0.3774
# Epoch 3/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.3634 - val_loss: 0.3081
# Epoch 4/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.3233 - val_loss: 0.2710
# Epoch 5/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.2916 - val_loss: 0.2404
# Epoch 6/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.2674 - val_loss: 0.2157
# Epoch 7/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2494 - val_loss: 0.2014
# Epoch 8/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2392 - val_loss: 0.1921
# Epoch 9/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2304 - val_loss: 0.1850
# Epoch 10/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.2230 - val_loss: 0.1782
# Epoch 11/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2173 - val_loss: 0.1741
# Epoch 12/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.2135 - val_loss: 0.1688
# Epoch 13/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.2103 - val_loss: 0.1663
# Epoch 14/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.2070 - val_loss: 0.1604
# Epoch 15/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2014 - val_loss: 0.1577
# Epoch 16/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1991 - val_loss: 0.1536
# Epoch 17/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1958 - val_loss: 0.1531
# Epoch 18/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1925 - val_loss: 0.1479
# Epoch 19/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1911 - val_loss: 0.1459
# Epoch 20/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1880 - val_loss: 0.1434
# Epoch 21/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1854 - val_loss: 0.1413
# Epoch 22/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1838 - val_loss: 0.1388
# Epoch 23/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.1810 - val_loss: 0.1361
# Epoch 24/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1801 - val_loss: 0.1361
# Epoch 25/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1775 - val_loss: 0.1347
# Epoch 26/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.1761 - val_loss: 0.1324
# Epoch 27/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1738 - val_loss: 0.1306
# Epoch 28/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1727 - val_loss: 0.1288
# Epoch 29/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1713 - val_loss: 0.1268
# Epoch 30/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1705 - val_loss: 0.1264
# Epoch 31/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.1688 - val_loss: 0.1247
# Epoch 32/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.1678 - val_loss: 0.1249
# Epoch 33/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.1667 - val_loss: 0.1225
# Epoch 34/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.1653 - val_loss: 0.1226
# Epoch 35/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1642 - val_loss: 0.1216
# Epoch 36/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1634 - val_loss: 0.1187
# Epoch 37/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.1620 - val_loss: 0.1186
# Epoch 38/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.1615 - val_loss: 0.1207
# Epoch 39/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1625 - val_loss: 0.1173
# Epoch 40/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1597 - val_loss: 0.1163
# Epoch 41/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1593 - val_loss: 0.1158
# Epoch 42/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1583 - val_loss: 0.1141
# Epoch 43/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.1567 - val_loss: 0.1133
# Epoch 44/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1560 - val_loss: 0.1136
# Epoch 45/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1559 - val_loss: 0.1115
# Epoch 46/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.1547 - val_loss: 0.1109
# Epoch 47/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.1543 - val_loss: 0.1107
# Epoch 48/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.1534 - val_loss: 0.1097
# Epoch 49/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1531 - val_loss: 0.1105
# Epoch 50/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.1536 - val_loss: 0.1095
# Epoch 51/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.1528 - val_loss: 0.1111
# Epoch 52/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.1511 - val_loss: 0.1090
# Epoch 53/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1503 - val_loss: 0.1072
# Epoch 54/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1506 - val_loss: 0.1102
# Epoch 55/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.1494 - val_loss: 0.1071
# Epoch 56/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.1486 - val_loss: 0.1067
# Epoch 57/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.1475 - val_loss: 0.1051
# Epoch 58/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1469 - val_loss: 0.1058
# Epoch 59/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.1467 - val_loss: 0.1042
# Epoch 60/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1466 - val_loss: 0.1035
# Epoch 61/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.1455 - val_loss: 0.1018
# Epoch 62/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 0.1454 - val_loss: 0.1039
# Epoch 63/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1443 - val_loss: 0.1029
# Epoch 64/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.1442 - val_loss: 0.1041
# Epoch 65/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.1437 - val_loss: 0.1017
# Epoch 66/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.1427 - val_loss: 0.1015
# Epoch 67/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1424 - val_loss: 0.1017
# Epoch 68/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1418 - val_loss: 0.1011
# Epoch 69/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.1419 - val_loss: 0.1010
# Epoch 70/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1409 - val_loss: 0.1023
# Epoch 71/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1406 - val_loss: 0.0990
# Epoch 72/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1405 - val_loss: 0.0976
# Epoch 73/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.1392 - val_loss: 0.0988
# Epoch 74/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1395 - val_loss: 0.0992
# Epoch 75/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.1390 - val_loss: 0.0966
# Epoch 76/200
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1384 - val_loss: 0.0980
# Epoch 77/200
# 96/98 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1387

# %%
autoencoder.summary()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Autoencoder Training")

plt.legend()

plt.show()

# %%
latent_train = encoder_model.predict(X_train_scaled)

latent_test = encoder_model.predict(X_test_scaled)

print("Train:", latent_train.shape)
print("Test :", latent_test.shape)
# Out:
# 1945/1945 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step
# Train: (248867, 10)
# Test : (62217, 10)

# %%
latent_columns = [f"latent_{i+1}" for i in range(10)]

latent_train = pd.DataFrame(
    latent_train,
    columns=latent_columns
)

latent_test = pd.DataFrame(
    latent_test,
    columns=latent_columns
)

# %%
latent_test.hist(
    figsize=(15,8),
    bins=30
)

plt.tight_layout()
plt.show()

# %%
iso_forest = IsolationForest(
    n_estimators=200,
    contamination="auto",
    random_state=42,
    n_jobs=-1
)

# %%
iso_forest.fit(latent_train)
# Out:
# IsolationForest(n_estimators=200, n_jobs=-1, random_state=42)

# %%
predictions = iso_forest.predict(latent_test)
anomaly_scores = -iso_forest.score_samples(latent_test)

# %%
results = latent_test.copy()

results["anomaly_score"] = anomaly_scores

results["prediction"] = predictions

results.head()
# Out:
#    latent_1  latent_2  latent_3  latent_4  latent_5  latent_6  latent_7  \
# 0 -0.313653  1.115190 -0.775199 -0.788022 -1.382125 -6.615431 -0.805622
# 1  0.207531  0.821929  0.096102 -0.892673 -0.239260 -4.280416 -0.722825
# 2  0.540787  0.580657 -1.157405 -0.321795 -0.749690 -4.291718 -0.475259
# 3 -0.633418  2.567680 -2.258440 -1.681981 -0.402666 -4.717012 -1.306336
# 4  0.056401  0.442710 -0.226658 -0.531226 -0.323535 -3.362446 -0.351885
#
#    latent_8  latent_9  latent_10  anomaly_score  prediction
# 0 -2.869648 -6.008152  -0.924199       0.419573           1
# 1 -1.688746 -3.059336  -0.252581       0.350527           1
# 2 -1.448904 -3.591671  -1.015772       0.374747           1
# 3 -3.135061 -3.878584   0.033231       0.429685           1
# 4 -1.867495 -3.158736  -0.920736       0.364325           1

# %%
plt.figure(figsize=(8,5))

plt.hist(anomaly_scores,
         bins=50)

plt.xlabel("Anomaly Score")

plt.ylabel("Number of Flows")

plt.title("Isolation Forest Anomaly Score Distribution")

plt.show()

# %%
score_series = pd.Series(anomaly_scores)

print(score_series.describe())

print("\nSkewness:", score_series.skew())
# Out:
# count    62217.000000
# mean         0.417287
# std          0.062216
# min          0.347878
# 25%          0.377184
# 50%          0.394556
# 75%          0.432100
# max          0.789663
# dtype: float64
#
# Skewness: 1.9494060852835424

# %%
print("Normal flows :", np.sum(predictions == 1))
print("Anomalous flows :", np.sum(predictions == -1))
# Out:
# Normal flows : 54745
# Anomalous flows : 7472

# %%
results = df.loc[X_test.index].copy()
results["anomaly_score"] = anomaly_scores

# %%
threshold = np.percentile(anomaly_scores, 95)

normal = results[results["anomaly_score"] < threshold]
anomalous = results[results["anomaly_score"] >= threshold]

print("Normal flows:", len(normal))
print("Anomalous flows:", len(anomalous))
# Out:
# Normal flows: 59106
# Anomalous flows: 3111

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

latent_pca = pca.fit_transform(latent_test)

# %%
plt.figure(figsize=(8,6))

scatter = plt.scatter(
    latent_pca[:,0],
    latent_pca[:,1],
    c=anomaly_scores,
    cmap="viridis",
    s=10
)

plt.colorbar(scatter, label="Anomaly Score")

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.title("Latent Space Representation of QUIC Flows")

plt.show()

# %%
seeds = [42, 100, 200, 500]


score_df = pd.DataFrame(index=latent_test.index)

for seed in seeds:

    iso = IsolationForest(
        n_estimators=200,
        contamination="auto",
        random_state=seed
    )

    iso.fit(latent_train)

    score_df[f"Seed_{seed}"] = -iso.score_samples(latent_test)

score_df.head()
# Out:
#     Seed_42  Seed_100  Seed_200  Seed_500
# 0  0.419573  0.423863  0.418257  0.414306
# 1  0.350527  0.351871  0.350358  0.349572
# 2  0.374747  0.388177  0.377748  0.372381
# 3  0.429685  0.433349  0.433671  0.437313
# 4  0.364325  0.368238  0.358161  0.364873

# %%
correlation = score_df.corr()

correlation
# Out:
#            Seed_42  Seed_100  Seed_200  Seed_500
# Seed_42   1.000000  0.990082  0.992198  0.990927
# Seed_100  0.990082  1.000000  0.991521  0.990486
# Seed_200  0.992198  0.991521  1.000000  0.991336
# Seed_500  0.990927  0.990486  0.991336  1.000000

# %%
top_anomalies = {}

for column in score_df.columns:

    threshold = score_df[column].quantile(0.95)

    top_anomalies[column] = set(
        score_df.index[
            score_df[column] >= threshold
        ]
    )

# %%
from itertools import combinations

overlap_results = []

for seed_1, seed_2 in combinations(score_df.columns, 2):

    common = len(
        top_anomalies[seed_1].intersection(
            top_anomalies[seed_2]
        )
    )

    total = len(top_anomalies[seed_1])

    overlap = (common / total) * 100

    overlap_results.append([
        seed_1,
        seed_2,
        common,
        round(overlap,2)
    ])

overlap_df = pd.DataFrame(
    overlap_results,
    columns=[
        "Seed 1",
        "Seed 2",
        "Common Anomalies",
        "Overlap (%)"
    ]
)

overlap_df
# Out:
#      Seed 1    Seed 2  Common Anomalies  Overlap (%)
# 0   Seed_42  Seed_100              2730        87.75
# 1   Seed_42  Seed_200              2701        86.82
# 2   Seed_42  Seed_500              2740        88.07
# 3  Seed_100  Seed_200              2838        91.22
# 4  Seed_100  Seed_500              2784        89.49
# 5  Seed_200  Seed_500              2799        89.97

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Reduce latent space to 2D
pca = PCA(n_components=2, random_state=42)
latent_pca = pca.fit_transform(latent_test)

# Boolean masks
normal_mask = predictions == 1
anomaly_mask = predictions == -1

plt.figure(figsize=(10,8))

# Normal flows
plt.scatter(
    latent_pca[normal_mask,0],
    latent_pca[normal_mask,1],
    s=10,
    c='lightgrey',
    alpha=0.35,
    label='Normal'
)

# Anomalies
plt.scatter(
    latent_pca[anomaly_mask,0],
    latent_pca[anomaly_mask,1],
    s=18,
    c='red',
    alpha=0.85,
    label='Predicted Anomaly'
)

plt.xlabel(f"Principal Component 1 ({pca.explained_variance_ratio_[0]*100:.2f}%)")
plt.ylabel(f"Principal Component 2 ({pca.explained_variance_ratio_[1]*100:.2f}%)")
plt.title("Latent Space PCA with Isolation Forest Predictions")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette = silhouette_score(latent_test, predictions)

print(f"Silhouette Score: {silhouette:.4f}")
# Out:
# Silhouette Score: 0.5311

# %%
from sklearn.metrics import davies_bouldin_score

db_index = davies_bouldin_score(latent_test, predictions)

print(f"Davies-Bouldin Index: {db_index:.4f}")
# Out:
# Davies-Bouldin Index: 1.3684

# %%
results_df = pd.DataFrame(
    latent_test,
    columns=[f"latent_{i+1}" for i in range(latent_test.shape[1])]
)

results_df["flow_index"] = X_test.index
results_df["anomaly_score"] = anomaly_scores
results_df["prediction"] = predictions

# Put flow_index first
results_df = results_df[
    ["flow_index"] +
    [c for c in results_df.columns if c != "flow_index"]
]

results_df.head()
# Out:
#    flow_index  latent_1  latent_2  latent_3  latent_4  latent_5  latent_6  \
# 0       81886 -0.313653  1.115190 -0.775199 -0.788022 -1.382125 -6.615431
# 1      200552  0.207531  0.821929  0.096102 -0.892673 -0.239260 -4.280416
# 2      294573  0.540787  0.580657 -1.157405 -0.321795 -0.749690 -4.291718
# 3      136922 -0.633418  2.567680 -2.258440 -1.681981 -0.402666 -4.717012
# 4      166186  0.056401  0.442710 -0.226658 -0.531226 -0.323535 -3.362446
#
#    latent_7  latent_8  latent_9  latent_10  anomaly_score  prediction
# 0 -0.805622 -2.869648 -6.008152  -0.924199       0.419573           1
# 1 -0.722825 -1.688746 -3.059336  -0.252581       0.350527           1
# 2 -0.475259 -1.448904 -3.591671  -1.015772       0.374747           1
# 3 -1.306336 -3.135061 -3.878584   0.033231       0.429685           1
# 4 -0.351885 -1.867495 -3.158736  -0.920736       0.364325           1

# %%
results_df.to_parquet(
    "with_CID_results.parquet",
    index=False
)

# %%
X_test.to_parquet("with_CID_test_features.parquet")
