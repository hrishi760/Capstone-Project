# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

# %%
import tensorflow as tf

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_parquet("with_CID.parquet")


print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (287806, 40)
#    PPI_LEN  PPI_ROUNDTRIPS  log_ppi_duration  log_mean_ipt  log_std_ipt  \
# 0       30               7          0.031499      0.725937     1.249640
# 1       30               5          1.592902      4.879767     6.445720
# 2       19               6          0.158712      2.307834     3.386832
# 3       13               3          0.076961      1.967650     2.883625
# 4       23               5          0.249980      2.591354     3.277578
#
#    mean_packet_size  std_packet_size  direction_change_ratio  \
# 0        966.433333       496.378262                0.482759
# 1        431.633333       497.956055                0.310345
# 2        306.157895       459.089518                0.666667
# 3        444.230769       517.949085                0.416667
# 4        559.217391       538.014624                0.409091
#
#    forward_packet_ratio  occid_length  ...  log_byte_rate  avg_packet_size  \
# 0              0.466667            32  ...       8.992109       849.000000
# 1              0.566667             0  ...       8.132042       419.382353
# 2              0.526316             0  ...      10.516724       334.157895
# 3              0.307692             0  ...      11.247659       472.230769
# 4              0.434783             0  ...      10.769836       587.217391
#
#    log_byte_ratio  log_packet_ratio  quic_version_id  QUIC_TOKEN_LENGTH  \
# 0        0.458604          0.503905                1                  0
# 1        0.585601          0.818310                1                  0
# 2        1.036035          0.747214                1                  0
# 3        0.967936          0.367725                1                  0
# 4        0.851155          0.570545                3                  0
#
#    log_zero_rtt  zero_rtt_present  log_multiplexed  multiplexed
# 0      1.791759                 1         1.098612            1
# 1      0.000000                 0         0.000000            0
# 2      0.693147                 1         0.000000            0
# 3      0.000000                 0         0.000000            0
# 4      0.000000                 0         0.000000            0
#
# [5 rows x 40 columns]

# %%
X_train, X_test = train_test_split(
    df,
    test_size=0.20,
    random_state=42,
    shuffle=True
)

print("Training Shape :", X_train.shape)
print("Testing Shape  :", X_test.shape)
# Out:
# Training Shape : (230244, 40)
# Testing Shape  : (57562, 40)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(
    X_train_scaled,
    columns=df.columns,
    index=X_train.index
)

X_test_scaled = pd.DataFrame(
    X_test_scaled,
    columns=df.columns,
    index=X_test.index
)

# %%
from tensorflow.keras.layers import (
    Input, Dense, Dropout
)
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping


input_dim = X_train_scaled.shape[1]

input_layer = Input(shape=(input_dim,))

# Encoder
x = Dense(
    64,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(input_layer)
x = Dropout(0.1)(x)

x = Dense(
    32,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(x)
x = Dropout(0.1)(x)

x = Dense(
    16,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(x)

# Latent Space
latent = Dense(
    10,
    activation='linear',
    name='latent'
)(x)

# Decoder
x = Dense(16, activation='relu')(latent)
x = Dense(32, activation='relu')(x)
x = Dense(64, activation='relu')(x)

output_layer = Dense(
    input_dim,
    activation='linear'
)(x)

autoencoder = Model(input_layer, output_layer)
encoder_model = Model(input_layer, latent)

autoencoder.compile(
    optimizer='adam',
    loss='mse'
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

history = autoencoder.fit(
    X_train_scaled,
    X_train_scaled,
    epochs=200,
    batch_size=2048,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.7850 - val_loss: 0.5716
# Epoch 2/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.4885 - val_loss: 0.3833
# Epoch 3/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.3756 - val_loss: 0.3003
# Epoch 4/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.3160 - val_loss: 0.2503
# Epoch 5/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.2814 - val_loss: 0.2266
# Epoch 6/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2619 - val_loss: 0.2094
# Epoch 7/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.2486 - val_loss: 0.1998
# Epoch 8/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.2392 - val_loss: 0.1896
# Epoch 9/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.2316 - val_loss: 0.1841
# Epoch 10/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.2259 - val_loss: 0.1770
# Epoch 11/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2189 - val_loss: 0.1720
# Epoch 12/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.2140 - val_loss: 0.1683
# Epoch 13/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.2110 - val_loss: 0.1639
# Epoch 14/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2065 - val_loss: 0.1607
# Epoch 15/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2034 - val_loss: 0.1572
# Epoch 16/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2010 - val_loss: 0.1553
# Epoch 17/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1974 - val_loss: 0.1509
# Epoch 18/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.1945 - val_loss: 0.1511
# Epoch 19/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.1918 - val_loss: 0.1465
# Epoch 20/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 0.1909 - val_loss: 0.1453
# Epoch 21/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1880 - val_loss: 0.1439
# Epoch 22/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1862 - val_loss: 0.1428
# Epoch 23/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1858 - val_loss: 0.1398
# Epoch 24/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1828 - val_loss: 0.1389
# Epoch 25/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1814 - val_loss: 0.1362
# Epoch 26/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.1804 - val_loss: 0.1344
# Epoch 27/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1772 - val_loss: 0.1333
# Epoch 28/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1763 - val_loss: 0.1322
# Epoch 29/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1759 - val_loss: 0.1319
# Epoch 30/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1743 - val_loss: 0.1304
# Epoch 31/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1731 - val_loss: 0.1289
# Epoch 32/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1719 - val_loss: 0.1288
# Epoch 33/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1701 - val_loss: 0.1267
# Epoch 34/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1704 - val_loss: 0.1283
# Epoch 35/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1687 - val_loss: 0.1262
# Epoch 36/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1680 - val_loss: 0.1257
# Epoch 37/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1664 - val_loss: 0.1236
# Epoch 38/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1652 - val_loss: 0.1224
# Epoch 39/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1644 - val_loss: 0.1217
# Epoch 40/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1632 - val_loss: 0.1207
# Epoch 41/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1627 - val_loss: 0.1208
# Epoch 42/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1618 - val_loss: 0.1192
# Epoch 43/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1601 - val_loss: 0.1173
# Epoch 44/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1597 - val_loss: 0.1180
# Epoch 45/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1586 - val_loss: 0.1160
# Epoch 46/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1576 - val_loss: 0.1149
# Epoch 47/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1558 - val_loss: 0.1138
# Epoch 48/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1558 - val_loss: 0.1125
# Epoch 49/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1555 - val_loss: 0.1123
# Epoch 50/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1540 - val_loss: 0.1101
# Epoch 51/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1524 - val_loss: 0.1105
# Epoch 52/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1520 - val_loss: 0.1104
# Epoch 53/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1512 - val_loss: 0.1089
# Epoch 54/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.1500 - val_loss: 0.1079
# Epoch 55/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1494 - val_loss: 0.1070
# Epoch 56/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1482 - val_loss: 0.1065
# Epoch 57/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1475 - val_loss: 0.1066
# Epoch 58/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.1467 - val_loss: 0.1042
# Epoch 59/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1461 - val_loss: 0.1045
# Epoch 60/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1452 - val_loss: 0.1047
# Epoch 61/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1445 - val_loss: 0.1039
# Epoch 62/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1433 - val_loss: 0.1033
# Epoch 63/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1430 - val_loss: 0.1031
# Epoch 64/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1425 - val_loss: 0.1027
# Epoch 65/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1422 - val_loss: 0.1023
# Epoch 66/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1411 - val_loss: 0.1026
# Epoch 67/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1413 - val_loss: 0.1027
# Epoch 68/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.1400 - val_loss: 0.1018
# Epoch 69/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1403 - val_loss: 0.1020
# Epoch 70/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.1386 - val_loss: 0.1007
# Epoch 71/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1381 - val_loss: 0.1012
# Epoch 72/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1384 - val_loss: 0.1003
# Epoch 73/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.1377 - val_loss: 0.1004
# Epoch 74/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1373 - val_loss: 0.0990
# Epoch 75/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1372 - val_loss: 0.1012
# Epoch 76/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1378 - val_loss: 0.0996
# Epoch 77/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1359 - val_loss: 0.0997
# Epoch 78/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1357 - val_loss: 0.0988
# Epoch 79/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1344 - val_loss: 0.0981
# Epoch 80/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.1351 - val_loss: 0.0979
# Epoch 81/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1347 - val_loss: 0.0986
# Epoch 82/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1340 - val_loss: 0.0980
# Epoch 83/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1335 - val_loss: 0.0978
# Epoch 84/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1328 - val_loss: 0.0970
# Epoch 85/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1331 - val_loss: 0.0960
# Epoch 86/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1323 - val_loss: 0.0980
# Epoch 87/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1321 - val_loss: 0.0990
# Epoch 88/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1313 - val_loss: 0.0971
# Epoch 89/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1306 - val_loss: 0.0974
# Epoch 90/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1307 - val_loss: 0.0967
# Epoch 91/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1312 - val_loss: 0.0965
# Epoch 92/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1300 - val_loss: 0.0961
# Epoch 93/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1299 - val_loss: 0.0967
# Epoch 94/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1297 - val_loss: 0.0971
# Epoch 95/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1292 - val_loss: 0.0951
# Epoch 96/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1291 - val_loss: 0.0968
# Epoch 97/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1285 - val_loss: 0.0946
# Epoch 98/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1282 - val_loss: 0.0962
# Epoch 99/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1278 - val_loss: 0.0965
# Epoch 100/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1283 - val_loss: 0.0955
# Epoch 101/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.1273 - val_loss: 0.0953
# Epoch 102/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1266 - val_loss: 0.0948
# Epoch 103/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1272 - val_loss: 0.0954
# Epoch 104/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1264 - val_loss: 0.0950
# Epoch 105/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1266 - val_loss: 0.0957
# Epoch 106/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1260 - val_loss: 0.0931
# Epoch 107/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1256 - val_loss: 0.0944
# Epoch 108/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1258 - val_loss: 0.0934
# Epoch 109/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1247 - val_loss: 0.0957
# Epoch 110/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1246 - val_loss: 0.0942
# Epoch 111/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1246 - val_loss: 0.0933
# Epoch 112/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1246 - val_loss: 0.0930
# Epoch 113/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1237 - val_loss: 0.0927
# Epoch 114/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1245 - val_loss: 0.0919
# Epoch 115/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1233 - val_loss: 0.0930
# Epoch 116/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1231 - val_loss: 0.0920
# Epoch 117/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.1234 - val_loss: 0.0927
# Epoch 118/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1228 - val_loss: 0.0945
# Epoch 119/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1225 - val_loss: 0.0940
# Epoch 120/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1218 - val_loss: 0.0927
# Epoch 121/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1223 - val_loss: 0.0923
# Epoch 122/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1221 - val_loss: 0.0929
# Epoch 123/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1218 - val_loss: 0.0932
# Epoch 124/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1215 - val_loss: 0.0934
# Epoch 125/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1210 - val_loss: 0.0933
# Epoch 126/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1205 - val_loss: 0.0933
# Epoch 127/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1208 - val_loss: 0.0924
# Epoch 128/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1198 - val_loss: 0.0935
# Epoch 129/200
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1204 - val_loss: 0.0944
# Epoch 129: early stopping
# Restoring model weights from the end of the best epoch: 114.

# %%
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 40)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           2,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ latent (Dense)                       │ (None, 10)                  │             170 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 40)                  │           2,600 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 32,504 (126.97 KB)
#  Trainable params: 10,834 (42.32 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 21,670 (84.65 KB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Autoencoder Training")

plt.legend()

plt.show()

# %%
latent_train = encoder_model.predict(X_train_scaled)

latent_test = encoder_model.predict(X_test_scaled)

print("Train:", latent_train.shape)
print("Test :", latent_test.shape)
# Out:
# 7196/7196 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step
# 1799/1799 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# Train: (230244, 10)
# Test : (57562, 10)

# %%
latent_columns = [f"latent_{i+1}" for i in range(10)]

latent_train = pd.DataFrame(
    latent_train,
    columns=latent_columns
)

latent_test = pd.DataFrame(
    latent_test,
    columns=latent_columns
)

# %%
latent_test.hist(
    figsize=(15,8),
    bins=30
)

plt.tight_layout()
plt.show()

# %%
iso_forest = IsolationForest(
    n_estimators=200,
    contamination="auto",
    random_state=42,
    n_jobs=-1
)

# %%
iso_forest.fit(latent_train)
# Out:
# IsolationForest(n_estimators=200, n_jobs=-1, random_state=42)

# %%
predictions = iso_forest.predict(latent_test)
anomaly_scores = -iso_forest.score_samples(latent_test)

# %%
results = latent_test.copy()

results["anomaly_score"] = anomaly_scores

results["prediction"] = predictions

results.head()
# Out:
#    latent_1  latent_2  latent_3  latent_4  latent_5  latent_6  latent_7  \
# 0 -1.266302  1.940330  1.241000  0.970462 -1.827854  0.467922 -1.569725
# 1 -2.487125  2.647048  0.573161  1.597007 -2.564399  0.010447 -0.519994
# 2 -2.671152  4.410594  0.577962  2.274585 -5.725747  1.587666 -6.024339
# 3 -4.510920  4.723670 -0.386998 -0.905804 -4.511523  0.055703 -1.282845
# 4 -1.281169  3.033035  0.996856  1.072152 -2.729927  0.081372 -1.522327
#
#    latent_8   latent_9  latent_10  anomaly_score  prediction
# 0  2.783739   0.970711  -2.957227       0.371250           1
# 1  3.004950   3.040451  -4.728933       0.387583           1
# 2  7.146484  11.599361  -8.418946       0.629441          -1
# 3  4.017811   3.034674  -8.400583       0.525200          -1
# 4  2.018340   1.464018  -4.519988       0.369893           1

# %%
plt.figure(figsize=(8,5))

plt.hist(anomaly_scores,
         bins=50)

plt.xlabel("Anomaly Score")

plt.ylabel("Number of Flows")

plt.title("Isolation Forest Anomaly Score Distribution")

plt.show()

# %%
score_series = pd.Series(anomaly_scores)

print(score_series.describe())

print("\nSkewness:", score_series.skew())
# Out:
# count    57562.000000
# mean         0.420872
# std          0.063152
# min          0.349244
# 25%          0.377708
# 50%          0.397476
# 75%          0.447489
# max          0.808729
# dtype: float64
#
# Skewness: 1.9640497891275455

# %%
print("Normal flows :", np.sum(predictions == 1))
print("Anomalous flows :", np.sum(predictions == -1))
# Out:
# Normal flows : 51198
# Anomalous flows : 6364

# %%
results = df.loc[X_test.index].copy()
results["anomaly_score"] = anomaly_scores

# %%
threshold = np.percentile(anomaly_scores, 95)

normal = results[results["anomaly_score"] < threshold]
anomalous = results[results["anomaly_score"] >= threshold]

print("Normal flows:", len(normal))
print("Anomalous flows:", len(anomalous))
# Out:
# Normal flows: 54683
# Anomalous flows: 2879

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

latent_pca = pca.fit_transform(latent_test)

# %%
plt.figure(figsize=(8,6))

scatter = plt.scatter(
    latent_pca[:,0],
    latent_pca[:,1],
    c=anomaly_scores,
    cmap="viridis",
    s=10
)

plt.colorbar(scatter, label="Anomaly Score")

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.title("Latent Space Representation of QUIC Flows")

plt.show()

# %%
seeds = [42, 100, 200, 500]


score_df = pd.DataFrame(index=latent_test.index)

for seed in seeds:

    iso = IsolationForest(
        n_estimators=200,
        contamination="auto",
        random_state=seed
    )

    iso.fit(latent_train)

    score_df[f"Seed_{seed}"] = -iso.score_samples(latent_test)

score_df.head()
# Out:
#     Seed_42  Seed_100  Seed_200  Seed_500
# 0  0.371250  0.364215  0.373420  0.372741
# 1  0.387583  0.382776  0.383588  0.384130
# 2  0.629441  0.618812  0.619765  0.622841
# 3  0.525200  0.515417  0.520788  0.537983
# 4  0.369893  0.362081  0.365512  0.367768

# %%
correlation = score_df.corr()

correlation
# Out:
#            Seed_42  Seed_100  Seed_200  Seed_500
# Seed_42   1.000000  0.991743  0.991419  0.990417
# Seed_100  0.991743  1.000000  0.992628  0.992725
# Seed_200  0.991419  0.992628  1.000000  0.993613
# Seed_500  0.990417  0.992725  0.993613  1.000000

# %%
top_anomalies = {}

for column in score_df.columns:

    threshold = score_df[column].quantile(0.95)

    top_anomalies[column] = set(
        score_df.index[
            score_df[column] >= threshold
        ]
    )

# %%
from itertools import combinations

overlap_results = []

for seed_1, seed_2 in combinations(score_df.columns, 2):

    common = len(
        top_anomalies[seed_1].intersection(
            top_anomalies[seed_2]
        )
    )

    total = len(top_anomalies[seed_1])

    overlap = (common / total) * 100

    overlap_results.append([
        seed_1,
        seed_2,
        common,
        round(overlap,2)
    ])

overlap_df = pd.DataFrame(
    overlap_results,
    columns=[
        "Seed 1",
        "Seed 2",
        "Common Anomalies",
        "Overlap (%)"
    ]
)

overlap_df
# Out:
#      Seed 1    Seed 2  Common Anomalies  Overlap (%)
# 0   Seed_42  Seed_100              2666        92.60
# 1   Seed_42  Seed_200              2616        90.86
# 2   Seed_42  Seed_500              2524        87.67
# 3  Seed_100  Seed_200              2595        90.14
# 4  Seed_100  Seed_500              2507        87.08
# 5  Seed_200  Seed_500              2491        86.52

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Reduce latent space to 2D
pca = PCA(n_components=2, random_state=42)
latent_pca = pca.fit_transform(latent_test)

# Boolean masks
normal_mask = predictions == 1
anomaly_mask = predictions == -1

plt.figure(figsize=(10,8))

# Normal flows
plt.scatter(
    latent_pca[normal_mask,0],
    latent_pca[normal_mask,1],
    s=10,
    c='lightgrey',
    alpha=0.35,
    label='Normal'
)

# Anomalies
plt.scatter(
    latent_pca[anomaly_mask,0],
    latent_pca[anomaly_mask,1],
    s=18,
    c='red',
    alpha=0.85,
    label='Predicted Anomaly'
)

plt.xlabel(f"Principal Component 1 ({pca.explained_variance_ratio_[0]*100:.2f}%)")
plt.ylabel(f"Principal Component 2 ({pca.explained_variance_ratio_[1]*100:.2f}%)")
plt.title("Latent Space PCA with Isolation Forest Predictions")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette = silhouette_score(latent_test, predictions)

print(f"Silhouette Score: {silhouette:.4f}")
# Out:
# Silhouette Score: 0.5070

# %%
from sklearn.metrics import davies_bouldin_score

db_index = davies_bouldin_score(latent_test, predictions)

print(f"Davies-Bouldin Index: {db_index:.4f}")
# Out:
# Davies-Bouldin Index: 1.5929

# %%
results_df = pd.DataFrame(
    latent_test,
    columns=[f"latent_{i+1}" for i in range(latent_test.shape[1])]
)

results_df["flow_index"] = X_test.index
results_df["anomaly_score"] = anomaly_scores
results_df["prediction"] = predictions

# Put flow_index first
results_df = results_df[
    ["flow_index"] +
    [c for c in results_df.columns if c != "flow_index"]
]

results_df.head()
# Out:
#    flow_index  latent_1  latent_2  latent_3  latent_4  latent_5  latent_6  \
# 0      159464 -1.266302  1.940330  1.241000  0.970462 -1.827854  0.467922
# 1      115420 -2.487125  2.647048  0.573161  1.597007 -2.564399  0.010447
# 2       53464 -2.671152  4.410594  0.577962  2.274585 -5.725747  1.587666
# 3      192817 -4.510920  4.723670 -0.386998 -0.905804 -4.511523  0.055703
# 4      186365 -1.281169  3.033035  0.996856  1.072152 -2.729927  0.081372
#
#    latent_7  latent_8   latent_9  latent_10  anomaly_score  prediction
# 0 -1.569725  2.783739   0.970711  -2.957227       0.371250           1
# 1 -0.519994  3.004950   3.040451  -4.728933       0.387583           1
# 2 -6.024339  7.146484  11.599361  -8.418946       0.629441          -1
# 3 -1.282845  4.017811   3.034674  -8.400583       0.525200          -1
# 4 -1.522327  2.018340   1.464018  -4.519988       0.369893           1

# %%
results_df.to_parquet(
    "with_CID_results.parquet",
    index=False
)

# %%
X_test.to_parquet("with_CID_test_features.parquet")
