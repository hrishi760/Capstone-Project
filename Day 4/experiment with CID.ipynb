# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

# %%
import tensorflow as tf

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_parquet("with_CID.parquet")


print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (731512, 40)
#    PPI_LEN  PPI_ROUNDTRIPS  log_ppi_duration  log_mean_ipt  log_std_ipt  \
# 0       30               3          0.087095      1.394593     1.844657
# 1       30               8          0.786638      3.710315     5.200603
# 2       30               6          0.101654      1.518784     2.285496
# 3       25               5          0.226338      2.412336     3.506581
# 4       19               4          0.076035      1.640528     1.912475
#
#    mean_packet_size  std_packet_size  direction_change_ratio  \
# 0        305.066667       448.216609                0.206897
# 1        285.400000       426.120609                0.517241
# 2        551.833333       553.884530                0.379310
# 3        437.080000       515.110700                0.416667
# 4        485.894737       551.395635                0.444444
#
#    forward_packet_ratio  occid_length  ...  log_byte_rate  avg_packet_size  \
# 0              0.533333             0  ...       8.935008       362.574766
# 1              0.500000             0  ...       6.111156       250.441860
# 2              0.533333             0  ...       9.609840       566.285714
# 3              0.480000             0  ...      10.732316       465.080000
# 4              0.473684             6  ...      11.770143       533.894737
#
#    log_byte_ratio  log_packet_ratio  quic_version_id  QUIC_TOKEN_LENGTH  \
# 0        0.307033          0.603802                1                 70
# 1        1.381015          0.670158                1                 71
# 2        2.195140          0.847298                1                 70
# 3        0.590181          0.653926                1                 71
# 4        0.742657          0.641854                1                 70
#
#    log_zero_rtt  zero_rtt_present  log_multiplexed  multiplexed
# 0      1.791759                 1              0.0            0
# 1      1.098612                 1              0.0            0
# 2      0.693147                 1              0.0            0
# 3      0.693147                 1              0.0            0
# 4      1.609438                 1              0.0            0
#
# [5 rows x 40 columns]

# %%
X_train, X_test = train_test_split(
    df,
    test_size=0.20,
    random_state=42,
    shuffle=True
)

print("Training Shape :", X_train.shape)
print("Testing Shape  :", X_test.shape)
# Out:
# Training Shape : (585209, 40)
# Testing Shape  : (146303, 40)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(
    X_train_scaled,
    columns=df.columns,
    index=X_train.index
)

X_test_scaled = pd.DataFrame(
    X_test_scaled,
    columns=df.columns,
    index=X_test.index
)

# %%
from tensorflow.keras.layers import (
    Input, Dense, Dropout
)
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping


input_dim = X_train_scaled.shape[1]

input_layer = Input(shape=(input_dim,))

# Encoder
x = Dense(
    64,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(input_layer)
x = Dropout(0.1)(x)

x = Dense(
    32,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(x)
x = Dropout(0.1)(x)

x = Dense(
    16,
    activation='relu',
    kernel_regularizer=l2(1e-5)
)(x)

# Latent Space
latent = Dense(
    10,
    activation='linear',
    name='latent'
)(x)

# Decoder
x = Dense(16, activation='relu')(latent)
x = Dense(32, activation='relu')(x)
x = Dense(64, activation='relu')(x)

output_layer = Dense(
    input_dim,
    activation='linear'
)(x)

autoencoder = Model(input_layer, output_layer)
encoder_model = Model(input_layer, latent)

autoencoder.compile(
    optimizer='adam',
    loss='mse'
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

history = autoencoder.fit(
    X_train_scaled,
    X_train_scaled,
    epochs=200,
    batch_size=2048,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - loss: 0.5593 - val_loss: 0.3542
# Epoch 2/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.3082 - val_loss: 0.2343
# Epoch 3/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.2469 - val_loss: 0.1856
# Epoch 4/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.2225 - val_loss: 0.1675
# Epoch 5/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 0.2064 - val_loss: 0.1533
# Epoch 6/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 0.1964 - val_loss: 0.1452
# Epoch 7/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1896 - val_loss: 0.1435
# Epoch 8/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1820 - val_loss: 0.1335
# Epoch 9/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.1778 - val_loss: 0.1288
# Epoch 10/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1732 - val_loss: 0.1247
# Epoch 11/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1697 - val_loss: 0.1223
# Epoch 12/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1666 - val_loss: 0.1174
# Epoch 13/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1643 - val_loss: 0.1148
# Epoch 14/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.1601 - val_loss: 0.1106
# Epoch 15/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1570 - val_loss: 0.1086
# Epoch 16/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.1540 - val_loss: 0.1073
# Epoch 17/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1522 - val_loss: 0.1041
# Epoch 18/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1501 - val_loss: 0.1010
# Epoch 19/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.1480 - val_loss: 0.1000
# Epoch 20/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1456 - val_loss: 0.0987
# Epoch 21/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.1431 - val_loss: 0.0957
# Epoch 22/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.1414 - val_loss: 0.0946
# Epoch 23/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.1396 - val_loss: 0.0939
# Epoch 24/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.1386 - val_loss: 0.0913
# Epoch 25/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.1373 - val_loss: 0.0912
# Epoch 26/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.1360 - val_loss: 0.0892
# Epoch 27/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1351 - val_loss: 0.0882
# Epoch 28/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1334 - val_loss: 0.0874
# Epoch 29/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1190 - val_loss: 0.0786
# Epoch 46/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.1182 - val_loss: 0.0779
# Epoch 47/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1168 - val_loss: 0.0792
# Epoch 48/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1166 - val_loss: 0.0782
# Epoch 49/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1157 - val_loss: 0.0768
# Epoch 50/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1146 - val_loss: 0.0766
# Epoch 51/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1138 - val_loss: 0.0769
# Epoch 52/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.1131 - val_loss: 0.0766
# Epoch 53/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1138 - val_loss: 0.0779
# Epoch 54/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.1113 - val_loss: 0.0767
# Epoch 55/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1111 - val_loss: 0.0762
# Epoch 56/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1098 - val_loss: 0.0752
# Epoch 57/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1094 - val_loss: 0.0741
# Epoch 58/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1085 - val_loss: 0.0750
# Epoch 59/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1073 - val_loss: 0.0730
# Epoch 60/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1070 - val_loss: 0.0735
# Epoch 61/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1056 - val_loss: 0.0744
# Epoch 62/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1053 - val_loss: 0.0726
# Epoch 63/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1047 - val_loss: 0.0715
# Epoch 64/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1041 - val_loss: 0.0723
# Epoch 65/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1037 - val_loss: 0.0711
# Epoch 66/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1027 - val_loss: 0.0724
# Epoch 67/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1023 - val_loss: 0.0723
# Epoch 68/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1023 - val_loss: 0.0713
# Epoch 69/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1020 - val_loss: 0.0730
# Epoch 70/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1013 - val_loss: 0.0700
# Epoch 71/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1016 - val_loss: 0.0704
# Epoch 72/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1010 - val_loss: 0.0711
# Epoch 73/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1008 - val_loss: 0.0695
# Epoch 74/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.1002 - val_loss: 0.0735
# Epoch 75/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.1001 - val_loss: 0.0697
# Epoch 76/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0997 - val_loss: 0.0705
# Epoch 77/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0997 - val_loss: 0.0724
# Epoch 78/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0999 - val_loss: 0.0705
# Epoch 79/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0991 - val_loss: 0.0707
# Epoch 80/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0993 - val_loss: 0.0693
# Epoch 81/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0985 - val_loss: 0.0714
# Epoch 82/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0983 - val_loss: 0.0698
# Epoch 83/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0979 - val_loss: 0.0708
# Epoch 84/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0978 - val_loss: 0.0696
# Epoch 85/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0975 - val_loss: 0.0699
# Epoch 86/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0982 - val_loss: 0.0704
# Epoch 87/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0968 - val_loss: 0.0692
# Epoch 88/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0962 - val_loss: 0.0696
# Epoch 89/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0962 - val_loss: 0.0694
# Epoch 90/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0967 - val_loss: 0.0699
# Epoch 91/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0961 - val_loss: 0.0703
# Epoch 92/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0958 - val_loss: 0.0688
# Epoch 93/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0959 - val_loss: 0.0710
# Epoch 94/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0954 - val_loss: 0.0704
# Epoch 95/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0952 - val_loss: 0.0676
# Epoch 96/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0946 - val_loss: 0.0674
# Epoch 97/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0945 - val_loss: 0.0682
# Epoch 98/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0954 - val_loss: 0.0699
# Epoch 99/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0945 - val_loss: 0.0697
# Epoch 100/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0947 - val_loss: 0.0681
# Epoch 101/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0944 - val_loss: 0.0690
# Epoch 102/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0937 - val_loss: 0.0666
# Epoch 103/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0937 - val_loss: 0.0673
# Epoch 104/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0936 - val_loss: 0.0696
# Epoch 105/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0930 - val_loss: 0.0679
# Epoch 106/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0927 - val_loss: 0.0690
# Epoch 107/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0928 - val_loss: 0.0682
# Epoch 108/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0927 - val_loss: 0.0690
# Epoch 109/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0928 - val_loss: 0.0696
# Epoch 110/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0925 - val_loss: 0.0684
# Epoch 111/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0921 - val_loss: 0.0699
# Epoch 112/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0928 - val_loss: 0.0705
# Epoch 113/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0923 - val_loss: 0.0680
# Epoch 114/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0922 - val_loss: 0.0672
# Epoch 115/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0915 - val_loss: 0.0661
# Epoch 116/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0914 - val_loss: 0.0666
# Epoch 117/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0912 - val_loss: 0.0677
# Epoch 118/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0914 - val_loss: 0.0673
# Epoch 119/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0911 - val_loss: 0.0658
# Epoch 120/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0911 - val_loss: 0.0668
# Epoch 121/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0913 - val_loss: 0.0678
# Epoch 122/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0909 - val_loss: 0.0672
# Epoch 123/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0906 - val_loss: 0.0663
# Epoch 124/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0903 - val_loss: 0.0659
# Epoch 125/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0901 - val_loss: 0.0670
# Epoch 126/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0907 - val_loss: 0.0690
# Epoch 127/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0895 - val_loss: 0.0660
# Epoch 128/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0895 - val_loss: 0.0689
# Epoch 129/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0904 - val_loss: 0.0688
# Epoch 130/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0896 - val_loss: 0.0664
# Epoch 131/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0892 - val_loss: 0.0644
# Epoch 132/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0890 - val_loss: 0.0669
# Epoch 133/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0892 - val_loss: 0.0661
# Epoch 134/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0890 - val_loss: 0.0658
# Epoch 135/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0886 - val_loss: 0.0646
# Epoch 136/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0886 - val_loss: 0.0653
# Epoch 137/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0883 - val_loss: 0.0676
# Epoch 138/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0893 - val_loss: 0.0679
# Epoch 139/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0885 - val_loss: 0.0667
# Epoch 140/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0880 - val_loss: 0.0668
# Epoch 141/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0877 - val_loss: 0.0643
# Epoch 142/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0879 - val_loss: 0.0651
# Epoch 143/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0879 - val_loss: 0.0679
# Epoch 144/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0892 - val_loss: 0.0657
# Epoch 145/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0874 - val_loss: 0.0679
# Epoch 146/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0883 - val_loss: 0.0666
# Epoch 147/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0875 - val_loss: 0.0647
# Epoch 148/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0885 - val_loss: 0.0643
# Epoch 149/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0873 - val_loss: 0.0653
# Epoch 150/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0871 - val_loss: 0.0647
# Epoch 151/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0870 - val_loss: 0.0636
# Epoch 152/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0869 - val_loss: 0.0649
# Epoch 153/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0867 - val_loss: 0.0663
# Epoch 154/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0871 - val_loss: 0.0643
# Epoch 155/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0870 - val_loss: 0.0632
# Epoch 156/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0865 - val_loss: 0.0638
# Epoch 157/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0869 - val_loss: 0.0636
# Epoch 158/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0865 - val_loss: 0.0635
# Epoch 159/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0859 - val_loss: 0.0628
# Epoch 160/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0860 - val_loss: 0.0667
# Epoch 161/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0869 - val_loss: 0.0669
# Epoch 162/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0861 - val_loss: 0.0638
# Epoch 163/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0859 - val_loss: 0.0650
# Epoch 164/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0866 - val_loss: 0.0634
# Epoch 165/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0865 - val_loss: 0.0630
# Epoch 166/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0864 - val_loss: 0.0639
# Epoch 167/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0856 - val_loss: 0.0655
# Epoch 168/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0860 - val_loss: 0.0669
# Epoch 169/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0858 - val_loss: 0.0633
# Epoch 170/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0857 - val_loss: 0.0636
# Epoch 171/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0857 - val_loss: 0.0659
# Epoch 172/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0860 - val_loss: 0.0631
# Epoch 173/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0856 - val_loss: 0.0625
# Epoch 174/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0855 - val_loss: 0.0637
# Epoch 175/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0855 - val_loss: 0.0642
# Epoch 176/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0856 - val_loss: 0.0636
# Epoch 177/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0849 - val_loss: 0.0637
# Epoch 178/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0856 - val_loss: 0.0625
# Epoch 179/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0851 - val_loss: 0.0628
# Epoch 180/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0848 - val_loss: 0.0638
# Epoch 181/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0849 - val_loss: 0.0622
# Epoch 182/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0851 - val_loss: 0.0625
# Epoch 183/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0853 - val_loss: 0.0642
# Epoch 184/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0846 - val_loss: 0.0638
# Epoch 185/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0849 - val_loss: 0.0637
# Epoch 186/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0849 - val_loss: 0.0655
# Epoch 187/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0850 - val_loss: 0.0626
# Epoch 188/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0846 - val_loss: 0.0626
# Epoch 189/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0852 - val_loss: 0.0649
# Epoch 190/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0845 - val_loss: 0.0625
# Epoch 191/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0843 - val_loss: 0.0625
# Epoch 192/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0846 - val_loss: 0.0620
# Epoch 193/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0852 - val_loss: 0.0626
# Epoch 194/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0842 - val_loss: 0.0636
# Epoch 195/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0845 - val_loss: 0.0613
# Epoch 196/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0847 - val_loss: 0.0631
# Epoch 197/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0838 - val_loss: 0.0617
# Epoch 198/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0849 - val_loss: 0.0613
# Epoch 199/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0842 - val_loss: 0.0636
# Epoch 200/200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0842 - val_loss: 0.0644
# Restoring model weights from the end of the best epoch: 195.

# %%
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 40)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           2,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ latent (Dense)                       │ (None, 10)                  │             170 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 40)                  │           2,600 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 32,504 (126.97 KB)
#  Trainable params: 10,834 (42.32 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 21,670 (84.65 KB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Autoencoder Training")

plt.legend()

plt.show()

# %%
latent_train = encoder_model.predict(X_train_scaled)

latent_test = encoder_model.predict(X_test_scaled)

print("Train:", latent_train.shape)
print("Test :", latent_test.shape)
# Out:
# 18288/18288 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step
# 4572/4572 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step
# Train: (585209, 10)
# Test : (146303, 10)

# %%
latent_columns = [f"latent_{i+1}" for i in range(10)]

latent_train = pd.DataFrame(
    latent_train,
    columns=latent_columns
)

latent_test = pd.DataFrame(
    latent_test,
    columns=latent_columns
)

# %%
latent_test.hist(
    figsize=(15,8),
    bins=30
)

plt.tight_layout()
plt.show()

# %%
iso_forest = IsolationForest(
    n_estimators=200,
    contamination="auto",
    random_state=42,
    n_jobs=-1
)

# %%
iso_forest.fit(latent_train)
# Out:
# IsolationForest(n_estimators=200, n_jobs=-1, random_state=42)

# %%
predictions = iso_forest.predict(latent_test)
anomaly_scores = -iso_forest.score_samples(latent_test)

# %%
results = latent_test.copy()

results["anomaly_score"] = anomaly_scores

results["prediction"] = predictions

results.head()
# Out:
#    latent_1  latent_2  latent_3   latent_4  latent_5  latent_6  latent_7  \
# 0 -3.020737 -6.924387 -1.407889   4.893724 -2.332092 -0.254729 -0.654660
# 1 -0.744106 -1.938956 -0.801532   1.177023 -1.765471  0.082539 -0.516205
# 2 -1.514351 -4.115342 -2.811307  -0.365024 -1.835058  1.107105 -0.336060
# 3 -0.440787 -2.033391 -1.389398   1.360087 -1.696280  0.095122 -0.174509
# 4 -1.663719  1.326961  7.052585  11.305074 -5.390179  3.428523  3.607767
#
#    latent_8   latent_9  latent_10  anomaly_score  prediction
# 0  4.388127  -4.621559  -1.143328       0.459176           1
# 1  1.478542  -2.777368  -1.132162       0.355085           1
# 2  2.847429  -5.851046  -1.553733       0.394756           1
# 3  0.383513  -2.909667  -1.862735       0.379886           1
# 4  7.193875 -22.559107  -0.524469       0.675819          -1

# %%
plt.figure(figsize=(8,5))

plt.hist(anomaly_scores,
         bins=50)

plt.xlabel("Anomaly Score")

plt.ylabel("Number of Flows")

plt.title("Isolation Forest Anomaly Score Distribution")

plt.show()

# %%
score_series = pd.Series(anomaly_scores)

print(score_series.describe())

print("\nSkewness:", score_series.skew())
# Out:
# count    146303.000000
# mean          0.415143
# std           0.076583
# min           0.338016
# 25%           0.358380
# 50%           0.386589
# 75%           0.443713
# max           0.761418
# dtype: float64
#
# Skewness: 1.542218738233638

# %%
print("Normal flows :", np.sum(predictions == 1))
print("Anomalous flows :", np.sum(predictions == -1))
# Out:
# Normal flows : 125937
# Anomalous flows : 20366

# %%
results = df.loc[X_test.index].copy()
results["anomaly_score"] = anomaly_scores

# %%
threshold = np.percentile(anomaly_scores, 95)

normal = results[results["anomaly_score"] < threshold]
anomalous = results[results["anomaly_score"] >= threshold]

print("Normal flows:", len(normal))
print("Anomalous flows:", len(anomalous))
# Out:
# Normal flows: 138987
# Anomalous flows: 7316

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

latent_pca = pca.fit_transform(latent_test)

# %%
plt.figure(figsize=(8,6))

scatter = plt.scatter(
    latent_pca[:,0],
    latent_pca[:,1],
    c=anomaly_scores,
    cmap="viridis",
    s=10
)

plt.colorbar(scatter, label="Anomaly Score")

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.title("Latent Space Representation of QUIC Flows")

plt.show()

# %%
seeds = [42, 100, 200, 500]


score_df = pd.DataFrame(index=latent_test.index)

for seed in seeds:

    iso = IsolationForest(
        n_estimators=200,
        contamination="auto",
        random_state=seed
    )

    iso.fit(latent_train)

    score_df[f"Seed_{seed}"] = -iso.score_samples(latent_test)

score_df.head()
# Out:
#     Seed_42  Seed_100  Seed_200  Seed_500
# 0  0.459176  0.447787  0.450955  0.455534
# 1  0.355085  0.351686  0.356969  0.357523
# 2  0.394756  0.389615  0.396544  0.393969
# 3  0.379886  0.377073  0.378425  0.384652
# 4  0.675819  0.673281  0.654617  0.674184

# %%
correlation = score_df.corr()

correlation
# Out:
#            Seed_42  Seed_100  Seed_200  Seed_500
# Seed_42   1.000000  0.995050  0.994301  0.994266
# Seed_100  0.995050  1.000000  0.992710  0.995463
# Seed_200  0.994301  0.992710  1.000000  0.993695
# Seed_500  0.994266  0.995463  0.993695  1.000000

# %%
top_anomalies = {}

for column in score_df.columns:

    threshold = score_df[column].quantile(0.95)

    top_anomalies[column] = set(
        score_df.index[
            score_df[column] >= threshold
        ]
    )

# %%
from itertools import combinations

overlap_results = []

for seed_1, seed_2 in combinations(score_df.columns, 2):

    common = len(
        top_anomalies[seed_1].intersection(
            top_anomalies[seed_2]
        )
    )

    total = len(top_anomalies[seed_1])

    overlap = (common / total) * 100

    overlap_results.append([
        seed_1,
        seed_2,
        common,
        round(overlap,2)
    ])

overlap_df = pd.DataFrame(
    overlap_results,
    columns=[
        "Seed 1",
        "Seed 2",
        "Common Anomalies",
        "Overlap (%)"
    ]
)

overlap_df
# Out:
#      Seed 1    Seed 2  Common Anomalies  Overlap (%)
# 0   Seed_42  Seed_100              6907        94.41
# 1   Seed_42  Seed_200              6880        94.04
# 2   Seed_42  Seed_500              6905        94.38
# 3  Seed_100  Seed_200              6772        92.56
# 4  Seed_100  Seed_500              6909        94.44
# 5  Seed_200  Seed_500              6826        93.30

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Reduce latent space to 2D
pca = PCA(n_components=2, random_state=42)
latent_pca = pca.fit_transform(latent_test)

# Boolean masks
normal_mask = predictions == 1
anomaly_mask = predictions == -1

plt.figure(figsize=(10,8))

# Normal flows
plt.scatter(
    latent_pca[normal_mask,0],
    latent_pca[normal_mask,1],
    s=10,
    c='lightgrey',
    alpha=0.35,
    label='Normal'
)

# Anomalies
plt.scatter(
    latent_pca[anomaly_mask,0],
    latent_pca[anomaly_mask,1],
    s=18,
    c='red',
    alpha=0.85,
    label='Predicted Anomaly'
)

plt.xlabel(f"Principal Component 1 ({pca.explained_variance_ratio_[0]*100:.2f}%)")
plt.ylabel(f"Principal Component 2 ({pca.explained_variance_ratio_[1]*100:.2f}%)")
plt.title("Latent Space PCA with Isolation Forest Predictions")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette = silhouette_score(latent_test, predictions)

print(f"Silhouette Score: {silhouette:.4f}")
# Out:
# Silhouette Score: 0.5925

# %%
from sklearn.metrics import davies_bouldin_score

db_index = davies_bouldin_score(latent_test, predictions)

print(f"Davies-Bouldin Index: {db_index:.4f}")
# Out:
# Davies-Bouldin Index: 1.3462

# %%
results_df = pd.DataFrame(
    latent_test,
    columns=[f"latent_{i+1}" for i in range(latent_test.shape[1])]
)

results_df["flow_index"] = X_test.index
results_df["anomaly_score"] = anomaly_scores
results_df["prediction"] = predictions

# Put flow_index first
results_df = results_df[
    ["flow_index"] +
    [c for c in results_df.columns if c != "flow_index"]
]

results_df.head()
# Out:
#    flow_index  latent_1  latent_2  latent_3   latent_4  latent_5  latent_6  \
# 0      491814 -3.020737 -6.924387 -1.407889   4.893724 -2.332092 -0.254729
# 1      547209 -0.744106 -1.938956 -0.801532   1.177023 -1.765471  0.082539
# 2      313159 -1.514351 -4.115342 -2.811307  -0.365024 -1.835058  1.107105
# 3      417373 -0.440787 -2.033391 -1.389398   1.360087 -1.696280  0.095122
# 4      451613 -1.663719  1.326961  7.052585  11.305074 -5.390179  3.428523
#
#    latent_7  latent_8   latent_9  latent_10  anomaly_score  prediction
# 0 -0.654660  4.388127  -4.621559  -1.143328       0.459176           1
# 1 -0.516205  1.478542  -2.777368  -1.132162       0.355085           1
# 2 -0.336060  2.847429  -5.851046  -1.553733       0.394756           1
# 3 -0.174509  0.383513  -2.909667  -1.862735       0.379886           1
# 4  3.607767  7.193875 -22.559107  -0.524469       0.675819          -1

# %%
results_df.to_parquet(
   "with_CID_results.parquet",
    index=False
)

# %%
X_test.to_parquet("with_CID_test_features.parquet")
